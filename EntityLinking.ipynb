# %% [markdown]
# ## Entity Linking Algorithm Demo
# In this notebook, a whole demo will be presented. The linking result should be a combination of degree and school, or position and company.
#
# Author: Yucheng Liang

# %% [markdown]
# ## Import libs

# %%
import jieba
import re
import chardet
from gensim.models import KeyedVectors
import numpy as np
import pandas as pd
import math
import datetime
import prettytable as pt

# %% [markdown]
# ## Load File

# %%
def loadSchool():
    path1 = 'data/chinese_university_list.csv'
    school_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=4, names=["rank", "name", "code", "department", "city", "level", "notes"])
    school_df = pd.DataFrame(school_df, columns=['name'])
    
    path2 = 'data/all_university_list.csv'
    school_global_df = pd.read_csv(path2, header=None, delimiter=',', skiprows=2, names=['Name_en', 'name', 'rank', 'score', 'location'])
    school_global_df = pd.DataFrame(school_global_df, columns=['name'])
    
    school_df = pd.concat([school_df, school_global_df], axis=0, ignore_index=True)
    return school_df

# %%
def loadDegree():
    degree = {'name': ['本科', '硕士' ,'研究生', '博士']}
    degree_df = pd.DataFrame(degree)
    return degree_df

# %%
def loadCompany():
    path1 = 'data/company_list_ch.csv'
    company_ch_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=2, names=['rank', 'name', 'Location', 'Income'])
    company_ch_df = pd.DataFrame(company_ch_df, columns=['name'])
    path2 = 'data/member-data.csv'
    company_df = pd.read_csv(path2, header=None, delimiter=",", skiprows=2, names=['name', 'No.', 'Resume', 'Position'])
    company_df = pd.DataFrame(company_df, columns=['name'])
    company_ch_df = pd.concat([company_ch_df, company_df], axis=0, ignore_index=True)
    
    print(f'before dedup, company size: {company_ch_df.shape[0]}')
    company_ch_df = company_ch_df.drop_duplicates(subset=['name'], keep='first')
    print(f'after dedup, company size: {company_ch_df.shape[0]}')
    return company_ch_df

# %%
def loadPosition():
    path5 = 'data/position.csv'
    position_df1 = pd.read_csv(path5, header=None, delimiter=",", skiprows=1, names=['name'])
    position_df1 = pd.DataFrame(position_df1)

    path6 = 'data/member-data.csv'
    position_df2 = pd.read_csv(path6, header=None, delimiter=",", skiprows=1, names=['Company', 'No.', 'Resume', 'name'])
    position_df2 = pd.DataFrame(position_df2, columns=['name'])

    member_position_list = []
    # process position in member-data
    for index, row in position_df2.iterrows():
        position = row['name']
        if isinstance(position, float) or position == " " or position.isalpha():
            continue
        if "&" in position:
            temp1 = position.split('&')
            member_position_list += temp1
        elif " " in position:
            temp2 = position.split( )
            member_position_list += temp2
        else:
            member_position_list.append(position)

    position_df3 = pd.DataFrame(member_position_list, columns=['name'])
    position_df1 = pd.concat([position_df1, position_df3], axis=0, ignore_index=True)
    print(f'before dedup, position size: {position_df1.shape[0]}')
    position_df1 = position_df1.drop_duplicates(subset=['name'], keep='first')
    print(f'after dedup, position size: {position_df1.shape[0]}')
    # print(df1.head())
    return position_df1

# %%
def loadMember():
    path = 'data/member-data.csv'
    member_df = pd.read_csv(path, header=None, delimiter=",", skiprows=1, names=['Company', 'No.', 'Resume', 'Position'])
    member_df = pd.DataFrame(member_df, columns=['Resume'])
    return member_df

# %% [markdown]
# ## Preprocess Text
# + remove punctuations
# + remove stopwords
# + to lower letter for recognition later
# + generate N-grams to link entity

# %%
def removeStopWords(seglist):
    stopwords = {}
    fstop = open('data/stopwords_cn.txt', 'r', encoding='utf-8', errors='ignore')
    for w in fstop:
        stopwords[w.strip()] = w.strip()

    fstop.close()
    stopwords[' '] = ' '
    
    segListSanitized = []

    for word in seglist:
        # translation
        if word == 'omnigo':
            word = '酷刻'
        if word == 'Aibee':
            word = '爱笔'
        if word == 'ilife':
            word = '爱乐福'
        if word == 'oracleen':
            word = '爱芽'
        if word not in stopwords:
            segListSanitized.append(word)
    return segListSanitized

# %%
def preprocess(text):
    # remove punctuations
    text = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", text)
    text = text.lower()
    # seperate words
    words = jieba.cut(text, cut_all=False)
    seglist = list(words)
    # remove stopwords
    segListSanitized = removeStopWords(seglist)
    print(f'Before sanitize, len: {len(seglist)}. After sanitize, len: {len(segListSanitized)}')

    return segListSanitized

# %% [markdown]
# ## N-gram Algorithm

# %%
def getNgrams(wordList, n):
    '''
    This function only generete N-Grams
    '''
    output = []
    for i in range (len(wordList) - n + 1):
        n_gram_temp = "".join(wordList[i:i+n])
        output.append(n_gram_temp)
    return output

# %%
def generateNgrams(wordList, n):
    '''
    This function genereates [1, N]-Grams
    '''
    result = set()
    for i in range(n):
        temp = getNgrams(wordList, i+1)
        result = result | temp
    
    return result

# %%
def generateNgramsV2(wordList, n):
    '''
    This function genereates [1, N]-Grams
    '''
    result = []
    for i in range(n):
        temp_list = getNgrams(wordList, i+1)
        temp = list(set(temp_list))
        temp.sort(key=temp_list.index)
        result.append(temp)
        
    return result

# %% [markdown]
# ## Word Embedding

# %%
model = KeyedVectors.load('./test_50.bin')

# %%
def calculate_cosine_similarity(a, b):
    vector_a = np.mat(a)
    vector_b = np.mat(b)
    num = float(vector_a * vector_b.T)
    denom = np.linalg.norm(vector_a) * np.linalg.norm(vector_b)
    
    if denom == 0:
        return 0.0
    
    cos = num / denom
    sim = 0.5 + 0.5 * cos
    return sim

# %%
def calculate_IDF(df):
    company_num = 0
    m = dict()
    for index, row in df.iterrows():
        name = row['name']
        name = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", name)
        name = name.lower()
        if isinstance(name, float) or name == " ":
            continue
        company_num += 1
        words = jieba.cut(name, cut_all=False)
        word_list = list(words)
        for word in word_list:
            if word in m.keys():
                m[word] +=1
            else:
                m[word] = 1
    
    idf = dict()
    
    for (k, v) in m.items():
        idf[k] = math.log(((1+company_num) / v), 10)
    
    # Normalize min-max
    v = idf.values()
    max_value = max(v)
    min_value = min(v)
    denom = max_value - min_value
    for (k, v) in idf.items():
        idf[k] = (idf[k] - min_value) / denom

    return idf

# %%
def generateEmbeddings(name):
    words = jieba.cut(name, cut_all=False)
    word_list = list(words)
    v = np.zeros((200))
    for word in word_list:
        if word in model.vocab:
            v += model[word]
    
    v /= len(v)
    return v

# %%
def generateEmbeddingsWithIDF(name, idf):
    words = jieba.cut(name, cut_all=False)
    word_list = list(words)
    v = np.zeros((200))
    for word in word_list:
        if word in model.vocab:
            v += model[word] * idf[word]
    
    v /= len(v)
    return v

# %%
def preprocess_entity_list(df, model):
    '''
    df: dafaframe
    model: word embedding model
    '''
    
    df['embeddings'] = ''
    for index, row in df.iterrows():
        # df.loc[index, 'embeddings'] = z
        name = row['name']
        if isinstance(name, float):
            continue
        name = name.lower()
        if name in model.vocab:
            vec = model[name]
        else:
            vec = generateEmbeddings(name)
        df.set_value(index, 'embeddings', vec)

    return df

# %%
def preprocess_entity_list_withIDF(df, model, idf):
    '''
    df: dafaframe
    model: word embedding model
    idf: IDF for each word
    '''
    
    df['embeddings_idf'] = ''
    for index, row in df.iterrows():
        name = row['name']
        name = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", name)
        name = name.lower()
        if isinstance(name, float):
            continue
        if name in model.vocab:
            vec = model[name]
        else:
            vec = generateEmbeddingsWithIDF(name, idf)
        df.set_value(index, 'embeddings_idf', vec)

    return df

# %% [markdown]
# ## Entity Link

# %%
def linkEntity(output, model, company_df, position_df, school_df, degree_df, company_threshold1, company_threshold2, position_threshold, school_threshold, degree_threshold, f):
    company_entity = []
    position_entity = []
    school_entity = []
    degree_entity = []
    for index, li in enumerate(output):
        print(f'process {index}-Gram')
        print(f'process {index}-Gram', file=f)
        for term in li:
            if len(term) <= 1:
                continue
            if term in model.vocab:
                term_vec = model[term]

                # Link Company
                company_candidate = dict()
                for index, row in company_df.iterrows():
                    name = row['name']
                    if isinstance(name, float):
                        continue
                    name_vec = row['embeddings_idf']
                    sim = calculate_cosine_similarity(term_vec, name_vec)
                    if (sim > company_threshold1):
                        company_candidate[name] = sim
                if len(company_candidate) != 0:
                    company_candidate = sorted(company_candidate.items(), key=lambda item:item[1], reverse=True)
                    print(f'company entity found: {term}->{company_candidate[0][0]}, sim = {company_candidate[0][1]}')
                    print(f'company entity found: {term}->{company_candidate[0][0]}, sim = {company_candidate[0][1]}', file=f)
                    company_entity.append(company_candidate[0])
                    
                # Link Position
                position_candidate = dict()
                for index, row in position_df.iterrows():
                    name = row['name']
                    name_vec = row['embeddings']
                    sim = calculate_cosine_similarity(term_vec, name_vec)
                    if (sim > position_threshold):
                        position_candidate[name] = sim
                if len(position_candidate) != 0:
                    position_candidate = sorted(position_candidate.items(), key=lambda item:item[1], reverse=True)
                    print(f'position entity found: {term}->{position_candidate[0][0]}, sim = {position_candidate[0][1]}')
                    print(f'position entity found: {term}->{position_candidate[0][0]}, sim = {position_candidate[0][1]}', file=f)
                    position_entity.append(position_candidate[0])
                
                # Link School
                school_candidate = dict()
                for index, row in school_df.iterrows():
                    name = row['name']
                    if isinstance(name, float):
                        continue
                    name_vec = row['embeddings']
                    sim = calculate_cosine_similarity(term_vec, name_vec)
                    if (sim > school_threshold):
                        school_candidate[name] = sim
                if len(school_candidate) != 0:
                    school_candidate = sorted(school_candidate.items(), key=lambda item:item[1], reverse=True)
                    print(f'university entity found: {term}->{school_candidate[0][0]}, sim = {school_candidate[0][1]}')
                    print(f'university entity found: {term}->{school_candidate[0][0]}, sim = {school_candidate[0][1]}', file=f)
                    school_entity.append(school_candidate[0])
                    
                # Link Degree
                degree_candidate = dict()
                for index, row in degree_df.iterrows():
                    name = row['name']
                    name_vec = row['embeddings']
                    sim = calculate_cosine_similarity(term_vec, name_vec)
                    if (sim > degree_threshold):
                        degree_candidate[name] = sim
                if len(degree_candidate) != 0:
                    degree_candidate = sorted(degree_candidate.items(), key=lambda item:item[1], reverse=True)
                    print(f'degree entity found: {term}->{degree_candidate[0][0]}, sim = {degree_candidate[0][1]}')
                    print(f'degree entity found: {term}->{degree_candidate[0][0]}, sim = {degree_candidate[0][1]}', file=f)
                    degree_entity.append(degree_candidate[0])
            else:
                term_vec = generateEmbeddings(term)
                for index, row in company_df.iterrows():
                    name = row['name']
                    if isinstance(name, float):
                        continue
                    name_vec = row['embeddings']
                    sim = calculate_cosine_similarity(term_vec, name_vec)
                    if (sim == 0.0 or sim > company_threshold2):
                        is_match = exact_match(name, term)
                        if is_match:
                            print(f'company entity found by exact match: {term}->{name}')
                            print(f'company entity found by exact match: {term}->{name}', file=f)
                            company_entity.append([name, 1.0])
                            break
                
    return company_entity, position_entity, school_entity, degree_entity

# %%
def exact_match(entity, term):
    keyword = extractKeyword(term)
    is_match = False
    for key in keyword:
        idx = entity.find(key)
        if idx != -1:
            is_match = True
    return is_match

# %%
def extractKeyword(term):
    '''
    Extract keyword in a term, whose embedding can not be found in vocabulary
    Return a list
    '''
    words = jieba.cut(term, cut_all=False)
    word_list = list(words)
    if len(word_list) > 1:
        word_list = getNgrams(word_list, 2)
    v = np.zeros((200))
    keyword = []
    for word in word_list:
        if word not in model.vocab:
            keyword.append(word)
    return keyword

# %%
def print_table_company_position(company_entity, position_entity, f):
    company_list = []
    company_sim_list = []
    position_list = []
    position_sim_list = []
        
    min_len = min(len(company_entity), len(position_entity))
    
    for i, s in enumerate(company_entity):
        if i == min_len:
            break
        company_list.append(s[0])
        company_sim_list.append(s[1])

    for i, d in enumerate(position_entity):
        if i == min_len:
            break
        position_list.append(d[0])
        position_sim_list.append(d[1])

    tb = pt.PrettyTable()
    tb.add_column("Company", company_list)
    tb.add_column("Company_Similarity", company_sim_list)
    tb.add_column("Position", position_list)
    tb.add_column("Position_Similarity", position_sim_list)
    print(tb)
    print(tb, file=f)

# %%
def print_table_school_degree(school_entity, degree_entity,f ):
    school_list = []
    school_sim_list = []
    degree_list = []
    degree_sim_list = []

    if len(degree_entity) == 0:
        d = dict()
        d= ['本科', 1.0]
        degree_entity.append(d)
        
    min_len = min(len(school_entity), len(degree_entity))
    
    for i, s in enumerate(school_entity):
        if i == min_len:
            break
        school_list.append(s[0])
        school_sim_list.append(s[1])

    for i, d in enumerate(degree_entity):
        if i == min_len:
            break
        degree_list.append(d[0])
        degree_sim_list.append(d[1])

    tb = pt.PrettyTable()
    tb.add_column("School", school_list)
    tb.add_column("School_Similarity", school_sim_list)
    tb.add_column("Degree", degree_list)
    tb.add_column("Degree_Similarity", degree_sim_list)
    print(tb)
    print(tb, file=f)

# %%
def print_table(company_entity, position_entity, school_entity, degree_entity, f):
    print_table_company_position(company_entity, position_entity, f)
    print_table_school_degree(school_entity, degree_entity, f)

# %% [markdown]
# ## Main Function

# %%
company_df = loadCompany()
position_df = loadPosition()
school_df = loadSchool()
degree_df = loadDegree()
member_df = loadMember()
# Out:
# before dedup, company size: 11716
# after dedup, company size: 3571
# before dedup, position size: 5983
# after dedup, position size: 199

# %%
company_idf = calculate_IDF(company_df)
company_df = preprocess_entity_list(company_df, model)
company_df = preprocess_entity_list_withIDF(company_df, model, company_idf)
position_df = preprocess_entity_list(position_df, model)
school_df = preprocess_entity_list(school_df, model)
degree_df = preprocess_entity_list(degree_df, model)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\梁育诚\AppData\Local\Temp\jieba.cache
# Loading model cost 1.351 seconds.
# Prefix dict has been built succesfully.
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %% [markdown]
# ### Hyper Parameters

# %%
company_thres1 = 0.96
company_thres2 = 0.9
position_thres = 0.98
school_thres = 0.91
degree_thres = 0.91

# %% [markdown]
# ## Case Test

# %%
text1 = '__团队成员#1__先生是公司创始人,也是中国最有影响力的商界领袖之一。1982年,__团队成员#1__先生于华南理工大学毕业,进入TCL的前身-TTK家庭电器有限公司。1985年,他担任新成立的TCL通讯设备公司总经理,创立了TCL品牌。2003年,__团队成员#1__担任TCL集团股份有限公司董事长兼CEO,随后TCL集团整体上市。在他的领导下,2004年TCL一举收购了法国汤姆逊全球彩电业务与阿尔卡特全球手机业务。目前TCL集团已经成为拥有6万名员工,业务遍及全球80多个国家和地区。2013年,TCL集团营业总收入超过855亿元,液晶电视全球销量1766万台,实际产量全球第三,品牌销售全球第三;TCL手机全球销量5520万台,行业排名全球第五。2012年__团队成员#1__被新华网评为“最具社会责任感企业家”;2011年荣获《中国企业家》“最具影响力的25位企业领袖”终身成就奖;2009年被评为“CCTV中国经济年度人物十年商业领袖”;2008年获改革开放30年经济人物称号;2004年被评为Fortune杂志“亚洲年度经济人物”、TIME杂志和CNN全球最具影响力的25名商界人士,同年法国总统希拉克向__团队成员#1__先生颁发了法国国家荣誉勋章。__团队成员#1__是中共第十六大代表,第十届、第十一届、第十二届全国人大代表。__团队成员#1__担任的社会职务包括:中国电子视像行业协会会长;中国国际商会副会长;全国工商联执行委员、广东省工商联(总商会)副主席。'

# %%
output_path1 = 'output1.txt'
segListSanitized = preprocess(text1)
output = generateNgramsV2(segListSanitized, 3)
f1 = open(output_path1, "w", encoding='utf-8')
company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f1)
print_table(company_entity, position_entity, school_entity, degree_entity, f1)
f1.close()
print()
# Out:
# Before sanitize, len: 325. After sanitize, len: 239
# process 0-Gram
# position entity found: 创始人->创始人, sim = 1.000000029802326
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# university entity found: 华南理工大学->华南理工大学, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->董事长, sim = 1.000000029802326
# position entity found: ceo->CEO, sim = 1.0
# process 1-Gram
# position entity found: 公司创始人->公司创始人, sim = 1.0000000298023295
# process 2-Gram
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 |  创始人  |  1.000000029802326  |
# |     TCL集团股份有限公司      |        1.0         |  总经理  |  1.0000000596046448 |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+-------------------+--------+-------------------+
# |    School    | School_Similarity | Degree | Degree_Similarity |
# +--------------+-------------------+--------+-------------------+
# | 华南理工大学 | 1.000000029802326 |  本科  |        1.0        |
# +--------------+-------------------+--------+-------------------+

# %%
text2 = '__团队成员#13__先生,现任深圳市华星光电技术有限公司高级副总裁.1955 年9 月生,硕士,韩国籍.1973 年至1981 年,韩国延世大学材料工程本科毕业;1991年至1995 年,韩国延世大学材料工程研究生毕业,获硕士学位;2003 年至2006年,McGill University Business 专业MBA 毕业,获硕士学位.1981 年至1999年,历任LG 半导体有限公司制程工程师、存储器制程发展部部长、高级技术中心(ATC)主管、C3 工厂厂长、执行总监;2000 年至2009 年,历任LG PHILIPS液晶显示IT 业务总部执行副总裁、LG PHILIPS 液晶显示生产技术中心总部执行副总裁;2009 年至2010 年,任日本FUHRMEISTER 电子高级顾问;2010 年3 月至今,任深圳市华星光电技术有限公司高级副总裁、总裁、首席执行官等职。'

# %%
output_path2 = 'output2.txt'
segListSanitized = preprocess(text2)
output = generateNgramsV2(segListSanitized, 3)
f2 = open(output_path2, "w", encoding='utf-8')
company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f2)
print_table(company_entity, position_entity, school_entity, degree_entity, f2)
f2.close()
print()
# Out:
# Before sanitize, len: 188. After sanitize, len: 124
# process 0-Gram
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# degree entity found: 硕士->硕士, sim = 1.0
# university entity found: 延世大学->延世大学, sim = 1.000000029802326
# degree entity found: 本科毕业->本科, sim = 0.9349876046180725
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: mcgill->麦吉尔大学, sim = 0.9162431259445103
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 总裁->总裁, sim = 1.000000029802326
# process 1-Gram
# position entity found: 高级副总裁->高级副总裁, sim = 1.0000000596046448
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# company entity found by exact match: 半导体有限公司->山东华芯半导体有限公司
# position entity found: 执行副总裁->执行副总裁, sim = 1.0000000596046448
# position entity found: 首席执行官->首席执行官, sim = 1.0
# process 2-Gram
# company entity found by exact match: lg半导体有限公司->山东华芯半导体有限公司
# company entity found by exact match: 半导体有限公司制程->山东华芯半导体有限公司
# +------------------------+--------------------+----------+---------------------+
# |        Company         | Company_Similarity | Position | Position_Similarity |
# +------------------------+--------------------+----------+---------------------+
# | 山东华芯半导体有限公司 |        1.0         |  副总裁  |  1.000000029802326  |
# | 山东华芯半导体有限公司 |        1.0         |   部长   |  1.0000000596046448 |
# | 山东华芯半导体有限公司 |        1.0         |   总裁   |  1.000000029802326  |
# +------------------------+--------------------+----------+---------------------+
# +------------+--------------------+--------+--------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity  |
# +------------+--------------------+--------+--------------------+
# |  延世大学  | 1.000000029802326  |  硕士  |        1.0         |
# | 麦吉尔大学 | 0.9162431259445103 |  本科  | 0.9349876046180725 |
# +------------+--------------------+--------+--------------------+

# %%
text3 = '__团队成员#6__先生,1980年7月生,硕士研究生学历。2002年,福州大学经济学本科毕业;2006年,云南大学法律硕士研究生毕业。2006年8月至2014年2月,任职国泰君安证券股份有限公司,历任国泰君安证券香港公司财务顾问部高级经理、总经理,深圳总部机构客户部总监,从事香港与中国资本市场的投资银行业务。2014年3月加入TCL集团股份有限公司,任公司董事会办公室主任;2014年4月起任公司董事会秘书;2014年12月起任公司执委会成员;2015年4月起任TCL集团控股子公司全球播有限公司董事;2015年5月起任TCL通讯科技控股有限公司(02618.HK)非执行董事。'

# %%
output_path3 = 'output3.txt'
segListSanitized = preprocess(text3)
output = generateNgramsV2(segListSanitized, 3)
f3 = open(output_path3, "w", encoding='utf-8')
company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f3)
print_table(company_entity, position_entity, school_entity, degree_entity, f3)
f3.close()
print()
# Out:
# Before sanitize, len: 139. After sanitize, len: 111
# process 0-Gram
# degree entity found: 硕士->硕士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: 福州大学->福州大学, sim = 1.0000000596046448
# degree entity found: 本科毕业->本科, sim = 0.9349876046180725
# university entity found: 云南大学->云南大学, sim = 1.0000000596046448
# position entity found: 经理->经理, sim = 1.0000000596046448
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.0000000159812819
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# position entity found: 董事->董事, sim = 1.0
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# process 1-Gram
# degree entity found: 硕士研究生->硕士, sim = 0.9260654151439667
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# position entity found: 高级经理->高级经理, sim = 1.0
# position entity found: 董事会秘书->董事会秘书, sim = 1.0000000596046448
# company entity found by exact match: 科技控股->盛世乐居（武汉）科技控股有限公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 董事会办公室主任->董事会办公室主任, sim = 1.0
# company entity found by exact match: 科技控股有限公司->盛世乐居（武汉）科技控股有限公司
# position entity found: 非执行董事->非执行董事, sim = 1.0000000298023295
# +----------------------------------+--------------------+------------+---------------------+
# |             Company              | Company_Similarity |  Position  | Position_Similarity |
# +----------------------------------+--------------------+------------+---------------------+
# |       深圳坂云智行有限公司       | 1.0000000159812819 |    经理    |  1.0000000596046448 |
# |   尚科宁家（中国）科技有限公司   | 0.9905265283315191 |   总经理   |  1.0000000596046448 |
# |       多玛凯拔科技有限公司       | 1.0000000094492707 |    董事    |         1.0         |
# | 盛世乐居（武汉）科技控股有限公司 |        1.0         |  高级经理  |         1.0         |
# |       TCL集团股份有限公司        |        1.0         | 董事会秘书 |  1.0000000596046448 |
# | 盛世乐居（武汉）科技控股有限公司 |        1.0         |  执行董事  |  1.000000029802326  |
# +----------------------------------+--------------------+------------+---------------------+
# +----------+--------------------+--------+-------------------+
# |  School  | School_Similarity  | Degree | Degree_Similarity |
# +----------+--------------------+--------+-------------------+
# | 福州大学 | 1.0000000596046448 |  硕士  |        1.0        |
# | 云南大学 | 1.0000000596046448 | 研究生 |        1.0        |
# +----------+--------------------+--------+-------------------+

# %%
text4 = '__团队成员#1__，北京爱国者新能源科技发展有限公司 CEO。'

# %%
output_path4 = 'output4.txt'
segListSanitized = preprocess(text4)
output = generateNgramsV2(segListSanitized, 3)
f4 = open(output_path4, "w", encoding='utf-8')
company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f4)
print_table(company_entity, position_entity, school_entity, degree_entity, f4)
f4.close()
print()
# Out:
# Before sanitize, len: 16. After sanitize, len: 10
# process 0-Gram
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9760900424845506
# company entity found: 爱国者->爱国者电子科技有限公司, sim = 0.9713396702727501
# company entity found: 新能源->上海烯美新能源科技有限公司, sim = 0.9637615946079356
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9604227663245726
# position entity found: ceo->CEO, sim = 1.0
# process 1-Gram
# process 2-Gram
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 宝希（北京）科技有限公司 | 0.9760900424845506 |   CEO    |         1.0         |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+

# %%
text5 = '__团队成员#1__，Omnigo机器人CEO。毕业于华中科技大学，原uArm创始团队核心成员，uArm机械臂主创设计师。'

# %%
output_path5 = 'output5.txt'
segListSanitized = preprocess(text5)
output = generateNgramsV2(segListSanitized, 3)
f5 = open(output_path5, "w", encoding='utf-8')
company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f5)
print_table(company_entity, position_entity, school_entity, degree_entity, f5)
f5.close()
print()
# Out:
# Before sanitize, len: 27. After sanitize, len: 18
# process 0-Gram
# company entity found by exact match: 酷刻->广州酷刻科技有限公司
# position entity found: ceo->CEO, sim = 1.0
# university entity found: 华中科技大学->华中科技大学, sim = 1.0
# process 1-Gram
# process 2-Gram
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 广州酷刻科技有限公司 |        1.0         |   CEO    |         1.0         |
# +----------------------+--------------------+----------+---------------------+
# +--------------+-------------------+--------+-------------------+
# |    School    | School_Similarity | Degree | Degree_Similarity |
# +--------------+-------------------+--------+-------------------+
# | 华中科技大学 |        1.0        |  本科  |        1.0        |
# +--------------+-------------------+--------+-------------------+

# %% [markdown]
# ## Batch Process
# Output to a file each 50 cases

# %%
begin = 8800
finish = 8850
time_arr = []
f = open('output_batch_10.txt', "w", encoding="utf-8")
for index, row in member_df.iterrows():
    if index < begin:
        continue
    if index > finish:
        break
    print(f'Handle No.{index} text')
    print(f'Handle No.{index} text', file=f)
    start = datetime.datetime.now()
    text = row['Resume']
    segListSanitized = preprocess(text)
    output = generateNgramsV2(segListSanitized, 3)
    end0 = datetime.datetime.now()
    company_entity, position_entity, school_entity, degree_entity = linkEntity(output, model, company_df, position_df, school_df, degree_df, company_thres1, company_thres2, position_thres, school_thres, degree_thres, f)
    end1 = datetime.datetime.now()
    print_table(company_entity, position_entity, school_entity, degree_entity, f)
    print()
    end = datetime.datetime.now()
    print(f'cost time(proprocess): {end0 - start} sec')
    print(f'cost time(proprocess): {end0 - start} sec', file=f)
    print(f'cost time(match): {end1 - end0} sec')
    print(f'cost time(match): {end1 - end0} sec', file=f)
    print(f'cost time(e2e): {end - start} sec')
    print(f'cost time(e2e): {end - start} sec', file=f)
    time_arr.append(end-start)
    print('\n\n')
    print('\n\n', file=f)
    
total_time = datetime.timedelta(0)
for t in time_arr:
    total_time += t
    
avg_time = total_time / len(time_arr)
print('avg_time: ', avg_time)
print('avg_time: ', avg_time, file=f)
f.close()
# Out:
# Handle No.8800 text
# Before sanitize, len: 29. After sanitize, len: 21
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# company entity found: 比亚迪->比亚迪股份有限公司
# , sim = 0.9891521303540014
# company entity found: 深圳市->深圳市艾谷乐科技有限公司, sim = 0.9703117227058451
# company entity found: 通科技->深圳市睿拓通科技有限公司, sim = 0.9874302580485594
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.0000000159812819
# process 1-Gram
# company entity found by exact match: 深圳市量子->深圳市量子慧智科技有限公司
# company entity found by exact match: 通科技有限公司->北京智慧视通科技有限公司
# process 2-Gram
# company entity found by exact match: 组长深圳市量子->深圳市量子慧智科技有限公司
# company entity found by exact match: 深圳市量子通科技->深圳市量子慧智科技有限公司
# company entity found by exact match: 量子通科技有限公司->北京智慧视通科技有限公司
# company entity found by exact match: 通科技有限公司光学->湖南克拉视通科技有限公司
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002955 sec
# cost time(match): 0:00:48.691853 sec
# cost time(e2e): 0:00:48.698807 sec
#
#
#
# Handle No.8801 text
# Before sanitize, len: 30. After sanitize, len: 23
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004887 sec
# cost time(match): 0:01:51.989861 sec
# cost time(e2e): 0:01:51.997749 sec
#
#
#
# Handle No.8802 text
# Before sanitize, len: 45. After sanitize, len: 37
# process 0-Gram
# degree entity found: 研究生->研究生, sim = 1.0
# company entity found: 深圳市->深圳市艾谷乐科技有限公司, sim = 0.9703117227058451
# position entity found: 经理->经理, sim = 1.0000000596046448
# position entity found: 总工程师->总工程师, sim = 1.0
# process 1-Gram
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# process 2-Gram
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 深圳市艾谷乐科技有限公司 | 0.9703117227058451 |   经理   |  1.0000000596046448 |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.006003 sec
# cost time(match): 0:03:01.172953 sec
# cost time(e2e): 0:03:01.185141 sec
#
#
#
# Handle No.8803 text
# Before sanitize, len: 18. After sanitize, len: 13
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# process 1-Gram
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# process 2-Gram
# +----------------------+--------------------+------------+---------------------+
# |       Company        | Company_Similarity |  Position  | Position_Similarity |
# +----------------------+--------------------+------------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 | 高级工程师 |  1.0000000596046448 |
# +----------------------+--------------------+------------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004003 sec
# cost time(match): 0:01:03.851611 sec
# cost time(e2e): 0:01:03.860660 sec
#
#
#
# Handle No.8804 text
# Before sanitize, len: 14. After sanitize, len: 10
# process 0-Gram
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9673671171958235
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295311
# position entity found: 监事->监事, sim = 1.0
# process 1-Gram
# company entity found by exact match: 光电科技股份->安徽至博光电科技股份有限公司
# process 2-Gram
# company entity found by exact match: 九洲光电科技股份->安徽至博光电科技股份有限公司
# company entity found by exact match: 光电科技股份有限公司->安徽至博光电科技股份有限公司
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 |   监事   |         1.0         |
# +----------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003001 sec
# cost time(match): 0:00:47.992387 sec
# cost time(e2e): 0:00:48.000382 sec
#
#
#
# Handle No.8805 text
# Before sanitize, len: 415. After sanitize, len: 347
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# position entity found: 部长->部长, sim = 1.0000000596046448
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295311
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9673671171958235
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.0000000159812819
# company entity found: 成都->成都缔趣科技有限公司, sim = 0.9892862134700999
# company entity found: 深圳市->深圳市艾谷乐科技有限公司, sim = 0.9703117227058451
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# position entity found: 监事->监事, sim = 1.0
# process 1-Gram
# company entity found by exact match: 电子股份->宁波均胜电子股份有限公司
#
# position entity found: 监事会主席->监事会主席, sim = 1.0
# company entity found by exact match: 电子科技股份->安徽戈瑞电子科技股份有限公司
# company entity found by exact match: 九洲电器->深圳市九洲电器有限公司
# company entity found by exact match: 光电科技股份->安徽至博光电科技股份有限公司
# company entity found by exact match: 深圳市九洲->深圳市九洲电器有限公司
# process 2-Gram
# company entity found by exact match: 四川湖山电子->四川湖山电器股份有限公司
# company entity found by exact match: 湖山电子股份->宁波均胜电子股份有限公司
#
# company entity found by exact match: 电子股份有限公司->宁波均胜电子股份有限公司
#
# company entity found by exact match: 四川九州电子->四川九州电子科技股份有限公司
# company entity found by exact match: 九州电子科技股份->安徽戈瑞电子科技股份有限公司
# company entity found by exact match: 电子科技股份有限公司->安徽戈瑞电子科技股份有限公司
# company entity found by exact match: 四川九洲电器->深圳市九洲电器有限公司
# company entity found by exact match: 九洲电器股份->深圳市九洲电器有限公司
# company entity found by exact match: 九洲光电科技股份->安徽至博光电科技股份有限公司
# company entity found by exact match: 光电科技股份有限公司->安徽至博光电科技股份有限公司
# company entity found by exact match: 有限公司深圳市九洲->深圳市九洲电器有限公司
# company entity found by exact match: 深圳市九洲电器->深圳市九洲电器有限公司
# company entity found by exact match: 九洲电器有限公司->深圳市九洲电器有限公司
# company entity found by exact match: 公司深圳市九洲->深圳市九洲电器有限公司
# company entity found by exact match: 深圳市九洲电子->深圳市九洲电器有限公司
# +------------------------+--------------------+------------+---------------------+
# |        Company         | Company_Similarity |  Position  | Position_Similarity |
# +------------------------+--------------------+------------+---------------------+
# |  四川创燚科技有限公司  | 0.9913867313860034 |    部长    |  1.0000000596046448 |
# | 华立捷科技股份有限公司 | 0.9999999984295311 |    监事    |         1.0         |
# | 深圳市耐明光电有限公司 | 0.9673671171958235 | 监事会主席 |         1.0         |
# +------------------------+--------------------+------------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.034996 sec
# cost time(match): 0:11:27.050164 sec
# cost time(e2e): 0:11:27.092161 sec
#
#
#
# Handle No.8806 text
# Before sanitize, len: 159. After sanitize, len: 135
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 董事长->董事长, sim = 1.000000029802326
# process 1-Gram
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# process 2-Gram
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 |   部长   |  1.0000000596046448 |
# +----------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.015001 sec
# cost time(match): 0:07:13.346339 sec
# cost time(e2e): 0:07:13.366342 sec
#
#
#
# Handle No.8807 text
# Before sanitize, len: 40. After sanitize, len: 35
# process 0-Gram
# degree entity found: 研究生->研究生, sim = 1.0
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9677984481856302
# company entity found: 浙江->浙江方大智控科技有限公司, sim = 0.9857095331275332
# company entity found: 华泰->华泰集团有限公司
# , sim = 0.9843474893780242
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.005220 sec
# cost time(match): 0:02:15.049180 sec
# cost time(e2e): 0:02:15.059401 sec
#
#
#
# Handle No.8808 text
# Before sanitize, len: 11. After sanitize, len: 6
# process 0-Gram
# position entity found: 董事长->董事长, sim = 1.000000029802326
# process 1-Gram
# company entity found by exact match: 科能锂电->四川科能锂电有限公司
# process 2-Gram
# company entity found by exact match: 1科能锂电->四川科能锂电有限公司
# company entity found by exact match: 科能锂电董事长->四川科能锂电有限公司
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 四川科能锂电有限公司 |        1.0         |  董事长  |  1.000000029802326  |
# +----------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002998 sec
# cost time(match): 0:00:27.327901 sec
# cost time(e2e): 0:00:27.335085 sec
#
#
#
# Handle No.8809 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# company entity found by exact match: 南充首创->四川南充首创科技开发有限公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 四川南充首创科技开发有限公司 |        1.0         |   董事   |         1.0         |
# +------------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003002 sec
# cost time(match): 0:00:35.577675 sec
# cost time(e2e): 0:00:35.582677 sec
#
#
#
# Handle No.8810 text
# Before sanitize, len: 10. After sanitize, len: 5
# process 0-Gram
# position entity found: 创始人->创始人, sim = 1.000000029802326
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002997 sec
# cost time(match): 0:00:23.108627 sec
# cost time(e2e): 0:00:23.114627 sec
#
#
#
# Handle No.8811 text
# Before sanitize, len: 27. After sanitize, len: 18
# process 0-Gram
# company entity found: 智联->深圳市三诺声智联股份有限公司, sim = 0.9650618266851856
# position entity found: ceo->CEO, sim = 1.0
# university entity found: 西南财大->西南财经大学, sim = 0.9418134987354279
# company entity found: 极客->北京极科极客科技有限公司, sim = 0.978390080039617
# process 1-Gram
# company entity found by exact match: 智联万居->四川省智联万居信息技术服务有限公司
# process 2-Gram
# company entity found by exact match: 1智联万居->四川省智联万居信息技术服务有限公司
# company entity found by exact match: 智联万居ceo->四川省智联万居信息技术服务有限公司
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 深圳市三诺声智联股份有限公司 | 0.9650618266851856 |   CEO    |         1.0         |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+-------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity |
# +--------------+--------------------+--------+-------------------+
# | 西南财经大学 | 0.9418134987354279 |  本科  |        1.0        |
# +--------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004990 sec
# cost time(match): 0:01:25.743937 sec
# cost time(e2e): 0:01:25.754058 sec
#
#
#
# Handle No.8812 text
# Before sanitize, len: 31. After sanitize, len: 21
# process 0-Gram
# company entity found: 智联->深圳市三诺声智联股份有限公司, sim = 0.9650618266851856
# position entity found: cto->CTO, sim = 1.0
# process 1-Gram
# company entity found by exact match: 智联万居->四川省智联万居信息技术服务有限公司
# process 2-Gram
# company entity found by exact match: 智联万居cto->四川省智联万居信息技术服务有限公司
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 深圳市三诺声智联股份有限公司 | 0.9650618266851856 |   CTO    |         1.0         |
# +------------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.006005 sec
# cost time(match): 0:01:41.429243 sec
# cost time(e2e): 0:01:41.440267 sec
#
#
#
# Handle No.8813 text
# Before sanitize, len: 28. After sanitize, len: 19
# process 0-Gram
# company entity found: 智联->深圳市三诺声智联股份有限公司, sim = 0.9650618266851856
# position entity found: 市场总监->市场总监, sim = 1.000000029802326
# university entity found: 西南财大->西南财经大学, sim = 0.9418134987354279
# process 1-Gram
# company entity found by exact match: 智联万居->四川省智联万居信息技术服务有限公司
# process 2-Gram
# company entity found by exact match: 智联万居市场总监->四川省智联万居信息技术服务有限公司
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 深圳市三诺声智联股份有限公司 | 0.9650618266851856 | 市场总监 |  1.000000029802326  |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+-------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity |
# +--------------+--------------------+--------+-------------------+
# | 西南财经大学 | 0.9418134987354279 |  本科  |        1.0        |
# +--------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.005184 sec
# cost time(match): 0:01:30.435722 sec
# cost time(e2e): 0:01:30.446027 sec
#
#
#
# Handle No.8814 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# position entity found: 董事->董事, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# process 1-Gram
# company entity found by exact match: 思诺创意->四川思诺创意科技有限公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# company entity found by exact match: 1思诺创意->四川思诺创意科技有限公司
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 四川思诺创意科技有限公司 |        1.0         |   董事   |         1.0         |
# | 四川思诺创意科技有限公司 |        1.0         |  总经理  |  1.0000000596046448 |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004700 sec
# cost time(match): 0:00:44.757725 sec
# cost time(e2e): 0:00:44.766271 sec
#
#
#
# Handle No.8815 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# company entity found by exact match: 斯普信->四川斯普信信息技术有限公司
# position entity found: 董事->董事, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# process 1-Gram
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# +----------------------------+--------------------+----------+---------------------+
# |          Company           | Company_Similarity | Position | Position_Similarity |
# +----------------------------+--------------------+----------+---------------------+
# |    四川创燚科技有限公司    | 0.9913867313860034 |   董事   |         1.0         |
# | 四川斯普信信息技术有限公司 |        1.0         |  总经理  |  1.0000000596046448 |
# +----------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003000 sec
# cost time(match): 0:00:41.589940 sec
# cost time(e2e): 0:00:41.599945 sec
#
#
#
# Handle No.8816 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# company entity found by exact match: 泰力智能仪表->四川泰力智能仪表科技有限公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# company entity found by exact match: 1泰力智能仪表->四川泰力智能仪表科技有限公司
# company entity found by exact match: 泰力智能仪表执行->四川泰力智能仪表科技有限公司
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 四川泰力智能仪表科技有限公司 |        1.0         |   董事   |         1.0         |
# | 四川泰力智能仪表科技有限公司 |        1.0         | 执行董事 |  1.000000029802326  |
# +------------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003595 sec
# cost time(match): 0:00:33.562316 sec
# cost time(e2e): 0:00:33.572279 sec
#
#
#
# Handle No.8817 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# position entity found: 董事->董事, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# process 1-Gram
# company entity found by exact match: 维优科技->四川维优科技有限责任公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# company entity found by exact match: 1维优科技->四川维优科技有限责任公司
# company entity found by exact match: 维优科技执行->四川维优科技有限责任公司
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# |   多玛凯拔科技有限公司   | 1.0000000094492707 |   董事   |         1.0         |
# | 四川维优科技有限责任公司 |        1.0         |  总经理  |  1.0000000596046448 |
# | 四川维优科技有限责任公司 |        1.0         | 执行董事 |  1.000000029802326  |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004004 sec
# cost time(match): 0:00:40.893817 sec
# cost time(e2e): 0:00:40.903859 sec
#
#
#
# Handle No.8818 text
# Before sanitize, len: 200. After sanitize, len: 171
# process 0-Gram
# degree entity found: 硕士->硕士, sim = 1.0
# company entity found: 成都->成都缔趣科技有限公司, sim = 0.9892862134700999
# company entity found: 重庆->重庆物联利浪科技有限公司, sim = 0.9916673248486179
# position entity found: 部长->部长, sim = 1.0000000596046448
# company entity found: 华润->中国华润有限公司
# , sim = 0.9632137595876921
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 电源->上海宝准电源科技有限公司, sim = 0.9605397603435344
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# position entity found: 董事->董事, sim = 1.0
# position entity found: 董事长->董事长, sim = 1.000000029802326
# process 1-Gram
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# position entity found: 常务副总经理->常务副总经理, sim = 1.0
# company entity found by exact match: 集团有限责任->国家能源投资集团有限责任公司
#
# company entity found by exact match: 能源有限公司->晶科能源有限公司
#
# process 2-Gram
# company entity found by exact match: 总经理四川省能源->四川省能源投资集团有限责任公司
#
# company entity found by exact match: 四川省能源投资->四川省能源投资集团有限责任公司
#
# company entity found by exact match: 投资集团有限责任->国家能源投资集团有限责任公司
#
# company entity found by exact match: 集团有限责任公司->国家能源投资集团有限责任公司
#
# company entity found by exact match: 分布式能源有限公司->晶科能源有限公司
#
# company entity found by exact match: 能源有限公司董事->晶科能源有限公司
#
# +------------------------------+--------------------+--------------+---------------------+
# |           Company            | Company_Similarity |   Position   | Position_Similarity |
# +------------------------------+--------------------+--------------+---------------------+
# |     成都缔趣科技有限公司     | 0.9892862134700999 |     部长     |  1.0000000596046448 |
# |   重庆物联利浪科技有限公司   | 0.9916673248486179 |   副总经理   |  1.0000000596046448 |
# |       中国华润有限公司       | 0.9632137595876921 |    总经理    |  1.0000000596046448 |
# |                              |                    |              |                     |
# |   上海宝准电源科技有限公司   | 0.9605397603435344 |     董事     |         1.0         |
# |     四川创燚科技有限公司     | 0.9913867313860034 |    董事长    |  1.000000029802326  |
# | 国家能源投资集团有限责任公司 |        1.0         |  高级工程师  |  1.0000000596046448 |
# |                              |                    |              |                     |
# |       晶科能源有限公司       |        1.0         | 常务副总经理 |         1.0         |
# |                              |                    |              |                     |
# +------------------------------+--------------------+--------------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.018653 sec
# cost time(match): 0:10:52.921736 sec
# cost time(e2e): 0:10:52.946392 sec
#
#
#
# Handle No.8819 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002997 sec
# cost time(match): 0:00:31.042098 sec
# cost time(e2e): 0:00:31.049096 sec
#
#
#
# Handle No.8820 text
# Before sanitize, len: 16. After sanitize, len: 11
# process 0-Gram
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003999 sec
# cost time(match): 0:00:50.230953 sec
# cost time(e2e): 0:00:50.237949 sec
#
#
#
# Handle No.8821 text
# Before sanitize, len: 53. After sanitize, len: 42
# process 0-Gram
# degree entity found: 大专->本科, sim = 0.9274712161702643
# position entity found: 监事->监事, sim = 1.0
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# process 1-Gram
# company entity found by exact match: 电子股份->宁波均胜电子股份有限公司
#
# process 2-Gram
# company entity found by exact match: 华翔电子股份->宁波均胜电子股份有限公司
#
# company entity found by exact match: 电子股份有限公司->宁波均胜电子股份有限公司
#
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 宁波均胜电子股份有限公司 |        1.0         |   监事   |         1.0         |
# |                          |                    |          |                     |
# | 宁波均胜电子股份有限公司 |        1.0         | 副总经理 |  1.0000000596046448 |
# |                          |                    |          |                     |
# | 宁波均胜电子股份有限公司 |        1.0         |  总经理  |  1.0000000596046448 |
# |                          |                    |          |                     |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.006002 sec
# cost time(match): 0:02:35.069681 sec
# cost time(e2e): 0:02:35.079725 sec
#
#
#
# Handle No.8822 text
# Before sanitize, len: 61. After sanitize, len: 46
# process 0-Gram
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9677984481856302
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# degree entity found: 研究生->研究生, sim = 1.0
# degree entity found: 硕士->硕士, sim = 1.0
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# university entity found: 电子科技大学->电子科技大学, sim = 1.0
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# position entity found: 执行副总裁->执行副总裁, sim = 1.0000000596046448
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 深圳市奥芯博电子科技有限公司 | 0.9677984481856302 |   部长   |  1.0000000596046448 |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+-------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity |
# +--------------+--------------------+--------+-------------------+
# |  贾达普大学  | 1.0000000084665304 | 研究生 |        1.0        |
# | 电子科技大学 |        1.0         |  硕士  |        1.0        |
# +--------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.005999 sec
# cost time(match): 0:03:25.443131 sec
# cost time(e2e): 0:03:25.454008 sec
#
#
#
# Handle No.8823 text
# Before sanitize, len: 96. After sanitize, len: 69
# process 0-Gram
# company entity found: 湖北->湖北仙盛科技股份有限公司, sim = 0.9776924338275976
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9677984481856302
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# degree entity found: 博士->博士, sim = 1.0
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 财务总监->财务总监, sim = 1.0
# position entity found: 总会计师->总会计师, sim = 1.0000000596046448
# position entity found: 副董事长->副董事长, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->董事长, sim = 1.000000029802326
# process 1-Gram
# university entity found: 电子科技大学->电子科技大学, sim = 1.0
# position entity found: 常务副总经理->常务副总经理, sim = 1.0
# company entity found by exact match: 压缩机股份->长虹华意压缩机股份有限公司
# company entity found by exact match: 美菱股份->长虹美菱股份有限公司
# process 2-Gram
# company entity found by exact match: 华意压缩机股份->长虹华意压缩机股份有限公司
# company entity found by exact match: 压缩机股份有限公司->长虹华意压缩机股份有限公司
# company entity found by exact match: 合肥美菱股份->长虹美菱股份有限公司
# +------------------------------+--------------------+--------------+---------------------+
# |           Company            | Company_Similarity |   Position   | Position_Similarity |
# +------------------------------+--------------------+--------------+---------------------+
# |   湖北仙盛科技股份有限公司   | 0.9776924338275976 |   副总经理   |  1.0000000596046448 |
# | 深圳市奥芯博电子科技有限公司 | 0.9677984481856302 |   财务总监   |         1.0         |
# |  长虹华意压缩机股份有限公司  |        1.0         |   总会计师   |  1.0000000596046448 |
# |     长虹美菱股份有限公司     |        1.0         |   副董事长   |         1.0         |
# |  长虹华意压缩机股份有限公司  |        1.0         |    总经理    |  1.0000000596046448 |
# |  长虹华意压缩机股份有限公司  |        1.0         |    董事长    |  1.000000029802326  |
# |     长虹美菱股份有限公司     |        1.0         | 常务副总经理 |         1.0         |
# +------------------------------+--------------------+--------------+---------------------+
# +------------+--------------------+--------+-------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity |
# +------------+--------------------+--------+-------------------+
# | 贾达普大学 | 1.0000000084665304 |  博士  |        1.0        |
# +------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.013052 sec
# cost time(match): 0:04:23.592602 sec
# cost time(e2e): 0:04:23.612657 sec
#
#
#
# Handle No.8824 text
# Before sanitize, len: 83. After sanitize, len: 63
# process 0-Gram
# university entity found: 西南财经大学->西南财经大学, sim = 1.0000000596046448
# degree entity found: 硕士->硕士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: 四川大学->四川大学, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# university entity found: 学院->马尼帕尔高等教育学院, sim = 0.9385821583210973
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# process 1-Gram
# degree entity found: 硕士研究生->硕士, sim = 0.9260654151439667
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# position entity found: 执行副总裁->执行副总裁, sim = 1.0000000596046448
# position entity found: 董事会秘书->董事会秘书, sim = 1.0000000596046448
# process 2-Gram
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 |   部长   |  1.0000000596046448 |
# +----------------------+--------------------+----------+---------------------+
# +----------------------+--------------------+--------+--------------------+
# |        School        | School_Similarity  | Degree | Degree_Similarity  |
# +----------------------+--------------------+--------+--------------------+
# |     西南财经大学     | 1.0000000596046448 |  硕士  |        1.0         |
# |       四川大学       |        1.0         | 研究生 |        1.0         |
# | 马尼帕尔高等教育学院 | 0.9385821583210973 |  硕士  | 0.9260654151439667 |
# +----------------------+--------------------+--------+--------------------+
#
# cost time(proprocess): 0:00:00.006960 sec
# cost time(match): 0:04:43.370491 sec
# cost time(e2e): 0:04:43.382405 sec
#
#
#
# Handle No.8825 text
# Before sanitize, len: 89. After sanitize, len: 66
# process 0-Gram
# university entity found: 四川大学->四川大学, sim = 1.0
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 董事->董事, sim = 1.0
# position entity found: 总工程师->总工程师, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# process 1-Gram
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# position entity found: 执行副总裁->执行副总裁, sim = 1.0000000596046448
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +----------+-------------------+--------+-------------------+
# |  School  | School_Similarity | Degree | Degree_Similarity |
# +----------+-------------------+--------+-------------------+
# | 四川大学 |        1.0        |  本科  |        1.0        |
# +----------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.010139 sec
# cost time(match): 0:03:59.540837 sec
# cost time(e2e): 0:03:59.551977 sec
#
#
#
# Handle No.8826 text
# Before sanitize, len: 114. After sanitize, len: 86
# process 0-Gram
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# degree entity found: 硕士->硕士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 经理->经理, sim = 1.0000000596046448
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# university entity found: 格拉斯哥大学->格拉斯哥大学, sim = 1.0000000596046448
# degree entity found: 硕士研究生->硕士, sim = 0.9260654151439667
# company entity found by exact match: 压缩机股份->长虹华意压缩机股份有限公司
# position entity found: 常务副总经理->常务副总经理, sim = 1.0
# process 2-Gram
# company entity found by exact match: 华意压缩机股份->长虹华意压缩机股份有限公司
# company entity found by exact match: 压缩机股份有限公司->长虹华意压缩机股份有限公司
# +----------------------------+--------------------+----------+---------------------+
# |          Company           | Company_Similarity | Position | Position_Similarity |
# +----------------------------+--------------------+----------+---------------------+
# |    四川创燚科技有限公司    | 0.9913867313860034 |   经理   |  1.0000000596046448 |
# | 长虹华意压缩机股份有限公司 |        1.0         | 副总经理 |  1.0000000596046448 |
# | 长虹华意压缩机股份有限公司 |        1.0         |   部长   |  1.0000000596046448 |
# | 长虹华意压缩机股份有限公司 |        1.0         |  总经理  |  1.0000000596046448 |
# +----------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+-------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity |
# +--------------+--------------------+--------+-------------------+
# |  贾达普大学  | 1.0000000084665304 |  硕士  |        1.0        |
# | 格拉斯哥大学 | 1.0000000596046448 | 研究生 |        1.0        |
# +--------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004008 sec
# cost time(match): 0:03:25.433719 sec
# cost time(e2e): 0:03:25.441733 sec
#
#
#
# Handle No.8827 text
# Before sanitize, len: 29. After sanitize, len: 19
# process 0-Gram
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9604227663245726
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003006 sec
# cost time(match): 0:00:52.181609 sec
# cost time(e2e): 0:00:52.187622 sec
#
#
#
# Handle No.8828 text
# Before sanitize, len: 73. After sanitize, len: 53
# process 0-Gram
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# process 1-Gram
# company entity found by exact match: 美菱股份->长虹美菱股份有限公司
# position entity found: 监事会主席->监事会主席, sim = 1.0
# process 2-Gram
# company entity found by exact match: 合肥美菱股份->长虹美菱股份有限公司
# +----------------------+--------------------+------------+---------------------+
# |       Company        | Company_Similarity |  Position  | Position_Similarity |
# +----------------------+--------------------+------------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 |    部长    |  1.0000000596046448 |
# | 长虹美菱股份有限公司 |        1.0         |   副总裁   |  1.000000029802326  |
# | 长虹美菱股份有限公司 |        1.0         | 监事会主席 |         1.0         |
# +----------------------+--------------------+------------+---------------------+
# +------------+--------------------+--------+-------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity |
# +------------+--------------------+--------+-------------------+
# | 贾达普大学 | 1.0000000084665304 |  本科  |        1.0        |
# +------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003003 sec
# cost time(match): 0:01:58.824276 sec
# cost time(e2e): 0:01:58.830282 sec
#
#
#
# Handle No.8829 text
# Before sanitize, len: 42. After sanitize, len: 30
# process 0-Gram
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002999 sec
# cost time(match): 0:01:22.042875 sec
# cost time(e2e): 0:01:22.047878 sec
#
#
#
# Handle No.8830 text
# Before sanitize, len: 78. After sanitize, len: 63
# process 0-Gram
# degree entity found: 博士->博士, sim = 1.0
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.007993 sec
# cost time(match): 0:02:42.181071 sec
# cost time(e2e): 0:02:42.192064 sec
#
#
#
# Handle No.8831 text
# Before sanitize, len: 129. After sanitize, len: 93
# process 0-Gram
# university entity found: 哈尔滨工程大学->哈尔滨工程大学, sim = 1.0
# university entity found: 学院->马尼帕尔高等教育学院, sim = 0.9385821583210973
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +----------------+-------------------+--------+-------------------+
# |     School     | School_Similarity | Degree | Degree_Similarity |
# +----------------+-------------------+--------+-------------------+
# | 哈尔滨工程大学 |        1.0        |  本科  |        1.0        |
# +----------------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.007998 sec
# cost time(match): 0:03:19.877805 sec
# cost time(e2e): 0:03:19.887802 sec
#
#
#
# Handle No.8832 text
# Before sanitize, len: 124. After sanitize, len: 96
# process 0-Gram
# degree entity found: 博士->博士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: 清华大学->清华大学, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# university entity found: 悉尼大学->悉尼大学, sim = 1.0000000596046448
# university entity found: 香港中文大学->香港中文大学, sim = 1.0
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295311
# position entity found: 董事->董事, sim = 1.0
# degree entity found: 教授->博士, sim = 0.9146097251540259
# degree entity found: 博士生->研究生, sim = 0.9329054355621338
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# company entity found: 控股集团->中运富通控股集团有限公司
# , sim = 0.9999999998383141
# process 1-Gram
# university entity found: 新南威尔士大学->新南威尔士大学, sim = 1.0
# position entity found: 独立董事->独立董事, sim = 1.0000000596046448
# company entity found by exact match: 声学股份->深圳市豪恩声学股份有限公司
# company entity found by exact match: 航空股份->中国国际航空股份有限公司
#
# company entity found by exact match: 控股集团股份->绿地控股集团股份有限公司
#
# process 2-Gram
# company entity found by exact match: 歌尔声学股份->深圳市豪恩声学股份有限公司
# company entity found by exact match: 声学股份有限公司->深圳市豪恩声学股份有限公司
# company entity found by exact match: 南方航空股份->中国国际航空股份有限公司
#
# company entity found by exact match: 航空股份有限公司->中国国际航空股份有限公司
#
# company entity found by exact match: 科技控股集团股份->绿地控股集团股份有限公司
#
# company entity found by exact match: 控股集团股份有限公司->绿地控股集团股份有限公司
#
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 |   董事   |         1.0         |
# |    华立捷科技股份有限公司    | 0.9999999984295311 | 独立董事 |  1.0000000596046448 |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+--------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity  |
# +--------------+--------------------+--------+--------------------+
# |   清华大学   |        1.0         |  博士  |        1.0         |
# |  贾达普大学  | 1.0000000084665304 | 研究生 |        1.0         |
# |   悉尼大学   | 1.0000000596046448 |  博士  | 0.9146097251540259 |
# | 香港中文大学 |        1.0         | 研究生 | 0.9329054355621338 |
# +--------------+--------------------+--------+--------------------+
#
# cost time(proprocess): 0:00:00.010998 sec
# cost time(match): 0:03:46.668954 sec
# cost time(e2e): 0:03:46.682951 sec
#
#
#
# Handle No.8833 text
# Before sanitize, len: 64. After sanitize, len: 44
# process 0-Gram
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# university entity found: 中国政法大学->中国政法大学, sim = 1.0
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9760900424845506
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# position entity found: 独立董事->独立董事, sim = 1.0000000596046448
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 |   董事   |         1.0         |
# |   宝希（北京）科技有限公司   | 0.9760900424845506 | 独立董事 |  1.0000000596046448 |
# +------------------------------+--------------------+----------+---------------------+
# +--------------+-------------------+--------+-------------------+
# |    School    | School_Similarity | Degree | Degree_Similarity |
# +--------------+-------------------+--------+-------------------+
# | 中国政法大学 |        1.0        |  本科  |        1.0        |
# +--------------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004009 sec
# cost time(match): 0:02:01.190018 sec
# cost time(e2e): 0:02:01.197008 sec
#
#
#
# Handle No.8834 text
# Before sanitize, len: 100. After sanitize, len: 75
# process 0-Gram
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# position entity found: 董事->董事, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295311
# company entity found: 东风汽车->东风汽车集团有限公司
# , sim = 0.9871500493782626
# process 1-Gram
# position entity found: 独立董事->独立董事, sim = 1.0000000596046448
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 |   董事   |         1.0         |
# |     四川创燚科技有限公司     | 0.9913867313860034 | 独立董事 |  1.0000000596046448 |
# +------------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# ...
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003005 sec
# cost time(match): 0:01:37.391070 sec
# cost time(e2e): 0:01:37.396076 sec
#
#
#
# Handle No.8839 text
# Before sanitize, len: 92. After sanitize, len: 69
# process 0-Gram
# company entity found: 江苏->江苏卫川物联科技有限公司, sim = 0.9876230304905382
# company entity found: 南京->南京控驰科技有限公司, sim = 0.9904987870454438
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# university entity found: 四川大学->四川大学, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# position entity found: 部长->部长, sim = 1.0000000596046448
# position entity found: 监事->监事, sim = 1.0
# process 1-Gram
# position entity found: 财务负责人->财务负责人, sim = 1.0
# company entity found by exact match: 美菱股份->长虹美菱股份有限公司
# process 2-Gram
# company entity found by exact match: 合肥美菱股份->长虹美菱股份有限公司
# +------------------------------+--------------------+------------+---------------------+
# |           Company            | Company_Similarity |  Position  | Position_Similarity |
# +------------------------------+--------------------+------------+---------------------+
# |   江苏卫川物联科技有限公司   | 0.9876230304905382 |    部长    |  1.0000000596046448 |
# |     南京控驰科技有限公司     | 0.9904987870454438 |    监事    |         1.0         |
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 | 财务负责人 |         1.0         |
# +------------------------------+--------------------+------------+---------------------+
# +------------+--------------------+--------+-------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity |
# +------------+--------------------+--------+-------------------+
# | 贾达普大学 | 1.0000000084665304 |  本科  |        1.0        |
# +------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003999 sec
# cost time(match): 0:02:01.645968 sec
# cost time(e2e): 0:02:01.651967 sec
#
#
#
# Handle No.8840 text
# Before sanitize, len: 73. After sanitize, len: 58
# process 0-Gram
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9913867313860034
# university entity found: 重庆大学->重庆大学, sim = 1.0000000596046448
# degree entity found: 硕士->硕士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 财务总监->财务总监, sim = 1.0
# position entity found: 经理->经理, sim = 1.0000000596046448
# position entity found: 部长->部长, sim = 1.0000000596046448
# process 1-Gram
# degree entity found: 硕士研究生->硕士, sim = 0.9260654151439667
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# process 2-Gram
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 四川创燚科技有限公司 | 0.9913867313860034 | 财务总监 |         1.0         |
# +----------------------+--------------------+----------+---------------------+
# +----------+--------------------+--------+-------------------+
# |  School  | School_Similarity  | Degree | Degree_Similarity |
# +----------+--------------------+--------+-------------------+
# | 重庆大学 | 1.0000000596046448 |  硕士  |        1.0        |
# +----------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.004002 sec
# cost time(match): 0:01:54.546113 sec
# cost time(e2e): 0:01:54.552084 sec
#
#
#
# Handle No.8841 text
# Before sanitize, len: 63. After sanitize, len: 43
# process 0-Gram
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# company entity found: 广东->广东爱霖科技有限公司, sim = 0.9824161707189226
# company entity found: 广州->广州酷刻科技有限公司, sim = 0.9869726659947173
# position entity found: 合伙人->合伙人, sim = 1.0
# process 1-Gram
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# | 尚科宁家（中国）科技有限公司 | 0.9905265283315191 |  合伙人  |         1.0         |
# +------------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003006 sec
# cost time(match): 0:01:19.389195 sec
# cost time(e2e): 0:01:19.394202 sec
#
#
#
# Handle No.8842 text
# Before sanitize, len: 49. After sanitize, len: 37
# process 0-Gram
# university entity found: 四川大学->四川大学, sim = 1.0
# degree entity found: 硕士->硕士, sim = 1.0
# university entity found: 理工大学->以色列理工学院, sim = 0.9112919064881784
# degree entity found: 博士->博士, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9905265283315191
# university entity found: 西南财经大学->西南财经大学, sim = 1.0000000596046448
# degree entity found: 博士生->研究生, sim = 0.9329054355621338
# process 1-Gram
# process 2-Gram
# university entity found: 皇家墨尔本理工大学->皇家墨尔本理工大学, sim = 1.0000000596046448
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +----------------+--------------------+--------+--------------------+
# |     School     | School_Similarity  | Degree | Degree_Similarity  |
# +----------------+--------------------+--------+--------------------+
# |    四川大学    |        1.0         |  硕士  |        1.0         |
# | 以色列理工学院 | 0.9112919064881784 |  博士  |        1.0         |
# |  西南财经大学  | 1.0000000596046448 | 研究生 | 0.9329054355621338 |
# +----------------+--------------------+--------+--------------------+
#
# cost time(proprocess): 0:00:00.003998 sec
# cost time(match): 0:01:31.240659 sec
# cost time(e2e): 0:01:31.246658 sec
#
#
#
# Handle No.8843 text
# Before sanitize, len: 69. After sanitize, len: 53
# process 0-Gram
# university entity found: 中国人民大学->中国人民大学, sim = 1.0
# degree entity found: 博士->博士, sim = 1.0
# university entity found: 麻省理工->麻省理工学院, sim = 0.9606197476387024
# university entity found: 学院->马尼帕尔高等教育学院, sim = 0.9385821583210973
# degree entity found: 博士生->研究生, sim = 0.9329054355621338
# university entity found: 清华大学->清华大学, sim = 1.0
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9760900424845506
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295311
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# position entity found: 独立董事->独立董事, sim = 1.0000000596046448
# process 2-Gram
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 宝希（北京）科技有限公司 | 0.9760900424845506 |   董事   |         1.0         |
# |  华立捷科技股份有限公司  | 0.9999999984295311 | 独立董事 |  1.0000000596046448 |
# +--------------------------+--------------------+----------+---------------------+
# +--------------+--------------------+--------+--------------------+
# |    School    | School_Similarity  | Degree | Degree_Similarity  |
# +--------------+--------------------+--------+--------------------+
# | 中国人民大学 |        1.0         |  博士  |        1.0         |
# | 麻省理工学院 | 0.9606197476387024 | 研究生 | 0.9329054355621338 |
# +--------------+--------------------+--------+--------------------+
#
# cost time(proprocess): 0:00:00.003976 sec
# cost time(match): 0:01:55.477643 sec
# cost time(e2e): 0:01:55.483622 sec
#
#
#
# Handle No.8844 text
# Before sanitize, len: 68. After sanitize, len: 52
# process 0-Gram
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# degree entity found: 本科毕业->本科, sim = 0.9349876046180725
# position entity found: 经理->经理, sim = 1.0000000596046448
# position entity found: 部长->部长, sim = 1.0000000596046448
# process 1-Gram
# process 2-Gram
# university entity found: 西南科技大学->西南科技大学, sim = 1.0
# +----------------------+--------------------+----------+---------------------+
# |       Company        | Company_Similarity | Position | Position_Similarity |
# +----------------------+--------------------+----------+---------------------+
# | 多玛凯拔科技有限公司 | 1.0000000094492707 |   经理   |  1.0000000596046448 |
# +----------------------+--------------------+----------+---------------------+
# +------------+--------------------+--------+--------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity  |
# +------------+--------------------+--------+--------------------+
# | 贾达普大学 | 1.0000000084665304 |  本科  | 0.9349876046180725 |
# +------------+--------------------+--------+--------------------+
#
# cost time(proprocess): 0:00:00.003024 sec
# cost time(match): 0:01:35.671834 sec
# cost time(e2e): 0:01:35.675829 sec
#
#
#
# Handle No.8845 text
# Before sanitize, len: 85. After sanitize, len: 62
# process 0-Gram
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# position entity found: 监事->监事, sim = 1.0
# position entity found: 部长->部长, sim = 1.0000000596046448
# process 1-Gram
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +------------+--------------------+--------+-------------------+
# |   School   | School_Similarity  | Degree | Degree_Similarity |
# +------------+--------------------+--------+-------------------+
# | 贾达普大学 | 1.0000000084665304 |  本科  |        1.0        |
# +------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.002984 sec
# cost time(match): 0:01:43.819635 sec
# cost time(e2e): 0:01:43.824617 sec
#
#
#
# Handle No.8846 text
# Before sanitize, len: 98. After sanitize, len: 72
# process 0-Gram
# university entity found: 清华大学->清华大学, sim = 1.0
# degree entity found: 博士->博士, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 副总经理->副总经理, sim = 1.0000000596046448
# position entity found: 副董事长->副董事长, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->董事长, sim = 1.000000029802326
# process 1-Gram
# degree entity found: 研究生毕业->研究生, sim = 0.9151657819747925
# position entity found: 高级工程师->高级工程师, sim = 1.0000000596046448
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +----------+-------------------+--------+-------------------+
# |  School  | School_Similarity | Degree | Degree_Similarity |
# +----------+-------------------+--------+-------------------+
# | 清华大学 |        1.0        |  博士  |        1.0        |
# +----------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003000 sec
# cost time(match): 0:01:55.307999 sec
# cost time(e2e): 0:01:55.313001 sec
#
#
#
# Handle No.8847 text
# Before sanitize, len: 63. After sanitize, len: 43
# process 0-Gram
# degree entity found: 本科->本科, sim = 1.0
# university entity found: 学院->马尼帕尔高等教育学院, sim = 0.9385821583210973
# degree entity found: 硕士->硕士, sim = 1.0
# process 1-Gram
# degree entity found: 硕士毕业->硕士, sim = 0.9301680624485016
# process 2-Gram
# +---------+--------------------+----------+---------------------+
# | Company | Company_Similarity | Position | Position_Similarity |
# +---------+--------------------+----------+---------------------+
# +---------+--------------------+----------+---------------------+
# +----------------------+--------------------+--------+-------------------+
# |        School        | School_Similarity  | Degree | Degree_Similarity |
# +----------------------+--------------------+--------+-------------------+
# | 马尼帕尔高等教育学院 | 0.9385821583210973 |  本科  |        1.0        |
# +----------------------+--------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.003011 sec
# cost time(match): 0:01:22.046524 sec
# cost time(e2e): 0:01:22.050517 sec
#
#
#
# Handle No.8848 text
# Before sanitize, len: 13. After sanitize, len: 8
# process 0-Gram
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492707
# position entity found: 董事->董事, sim = 1.0
# process 1-Gram
# company entity found by exact match: 智海联->四川智海联科技有限公司
# company entity found by exact match: 海联科技->四川智海联科技有限公司
# position entity found: 执行董事->执行董事, sim = 1.000000029802326
# process 2-Gram
# company entity found by exact match: 1智海联->四川智海联科技有限公司
# company entity found by exact match: 智海联科技->四川智海联科技有限公司
# company entity found by exact match: 海联科技执行->四川智海联科技有限公司
# +------------------------+--------------------+----------+---------------------+
# |        Company         | Company_Similarity | Position | Position_Similarity |
# +------------------------+--------------------+----------+---------------------+
# |  多玛凯拔科技有限公司  | 1.0000000094492707 |   董事   |         1.0         |
# | 四川智海联科技有限公司 |        1.0         | 执行董事 |  1.000000029802326  |
# +------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.001989 sec
# cost time(match): 0:00:13.009031 sec
# cost time(e2e): 0:00:13.011994 sec
#
#
#
# Handle No.8849 text
# Before sanitize, len: 104. After sanitize, len: 76
# process 0-Gram
# company entity found by exact match: 昆辰->四川中电昆辰科技有限公司
# position entity found: 董事长->董事长, sim = 1.000000029802326
# university entity found: 杜克大学->杜克大学, sim = 1.0
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9677984481856302
# university entity found: 大学->贾达普大学, sim = 1.0000000084665304
# degree entity found: 博士->博士, sim = 1.0
# company entity found: 成都->成都缔趣科技有限公司, sim = 0.9892862134700999
# position entity found: 算法->算法, sim = 1.000000029802326
# process 1-Gram
# university entity found: 电子科技大学->电子科技大学, sim = 1.0
# process 2-Gram
# +------------------------------+--------------------+----------+---------------------+
# |           Company            | Company_Similarity | Position | Position_Similarity |
# +------------------------------+--------------------+----------+---------------------+
# |   四川中电昆辰科技有限公司   |        1.0         |  董事长  |  1.000000029802326  |
# | 深圳市奥芯博电子科技有限公司 | 0.9677984481856302 |   算法   |  1.000000029802326  |
# +------------------------------+--------------------+----------+---------------------+
# +----------+-------------------+--------+-------------------+
# |  School  | School_Similarity | Degree | Degree_Similarity |
# +----------+-------------------+--------+-------------------+
# | 杜克大学 |        1.0        |  博士  |        1.0        |
# +----------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.009995 sec
# cost time(match): 0:02:19.492999 sec
# cost time(e2e): 0:02:19.505998 sec
#
#
#
# Handle No.8850 text
# Before sanitize, len: 55. After sanitize, len: 37
# process 0-Gram
# company entity found by exact match: 昆辰->四川中电昆辰科技有限公司
# position entity found: ceo->CEO, sim = 1.0
# company entity found: 实业->深圳市安科讯实业有限公司, sim = 0.9771979257585566
# process 1-Gram
# process 2-Gram
# +--------------------------+--------------------+----------+---------------------+
# |         Company          | Company_Similarity | Position | Position_Similarity |
# +--------------------------+--------------------+----------+---------------------+
# | 四川中电昆辰科技有限公司 |        1.0         |   CEO    |         1.0         |
# +--------------------------+--------------------+----------+---------------------+
# +--------+-------------------+--------+-------------------+
# | School | School_Similarity | Degree | Degree_Similarity |
# +--------+-------------------+--------+-------------------+
# +--------+-------------------+--------+-------------------+
#
# cost time(proprocess): 0:00:00.006998 sec
# cost time(match): 0:01:05.872132 sec
# cost time(e2e): 0:01:05.880131 sec
#
#
#
# avg_time:  0:02:18.159294

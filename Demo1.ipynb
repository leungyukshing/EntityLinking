# %% [markdown]
# # Demo1
# This is a demo. What I want to achieve?
# + link school, company, degree, position without order. Only find out those entities
# + batch process
# + have 3 mode: hard match, embedding, embedding with normalization

# %%
import jieba
import re
import chardet
from gensim.models import KeyedVectors
import numpy as np
import pandas as pd
import math

# %% [markdown]
# ## Load File

# %%
def loadSchool():
    path1 = 'data/chinese_university_list.csv'
    school_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=4, names=["rank", "name", "code", "department", "city", "level", "notes"])
    school_df = pd.DataFrame(school_df, columns=['name'])
    print(school_df.shape[0])
    
    path2 = 'data/all_university.csv'
    school_global_df = pd.read_csv(path2, header=None, delimiter=',', skiprows=4, names=['Name_en', 'Name_ch', 'rank', 'score', 'location'])
    school_global_df = pd.DataFrame(school_global_df, columns=['Name_ch'])
    print(school_global_df.shape[0])
    
    school_df = pd.concat([school_df, school_global_df], axis=0, ignore_index=True)
    print(school_df.shape[0])
    return school_df

# %%
def loadCompany():
    path1 = 'data/company_list_ch.csv'
    company_ch_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=2, names=['rank', 'name', 'Location', 'Income'])
    company_ch_df = pd.DataFrame(company_ch_df, columns=['name'])
    print(company_ch_df.shape[0])
    
    path2 = 'data/member-data.csv'
    company_df = pd.read_csv(path2, header=None, delimiter=",", skiprows=2, names=['name', 'No.', 'Resume', 'Position'])
    company_df = pd.DataFrame(company_df, columns=['name'])
    print(company_df.shape[0])
    
    company_ch_df = pd.concat([company_ch_df, company_df], axis=0, ignore_index=True)
    print(company_ch_df.shape[0])
    return company_ch_df

# %%
def loadDegree():
    degree = {'name': ['学士', '硕士', '博士']}
    degree_df = pd.DataFrame(degree)
    print(degree_df)
    return degree_df

# %%
def loadPosition():
    path = 'data/position.csv'
    position_df = pd.read_csv(path, header=None, delimiter=",", skiprows=1, names=['name'])
    print(position_df.head())
    return position_df

# %%
def loadMember():
    path = 'data/member-data.csv'
    member_df = pd.read_csv(path, header=None, delimiter=",", skiprows=1, names=['Company', 'No.', 'Resume', 'Position'])
    member_df = pd.DataFrame(member_df, columns=['Resume'])
    print(member_df.head())
    return member_df

# %% [markdown]
# # Preprocess Text
# + remove punctuations
# + remove stopwords
# + to lower letter for regconition later
# + generate N-grams to link entity

# %%
def removeStopWords(seglist):
    stopwords = {}
    fstop = open('data/stopwords_cn.txt', 'r', encoding='utf-8', errors='ignore')
    for w in fstop:
        stopwords[w.strip()] = w.strip()

    fstop.close()
    stopwords[' '] = ' '
    
    segListSanitized = []

    for word in seglist:
        if word not in stopwords:
            segListSanitized.append(word)
    return segListSanitized

# %%
def preprocess(text):
    # remove punctuations
    text = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", text)
    text = text.lower()
    # seperate words
    words = jieba.cut(text, cut_all=False)
    seglist = list(words)
    # remove stopwords
    segListSanitized = removeStopWords(seglist)
    print(f'Before sanitize, len: {len(seglist)}. After sanitize, len: {len(segListSanitized)}')

    return segListSanitized

# %% [markdown]
# ## N-gram Algorithm

# %%
def getNgrams(wordList, n):
    '''
    This function only generete N-Grams
    '''
    output = set()
    for i in range (len(wordList) - n + 1):
        n_gram_temp = "".join(wordList[i:i+n])
        output.add(n_gram_temp)
    return output

# %%
def generateNgrams(wordList, n):
    '''
    This function genereates [1, N]-Grams
    '''
    result = set()
    for i in range(n):
        temp = getNgrams(wordList, i+1)
        result = result | temp
    
    return result

# %% [markdown]
# ## Word Embedding

# %%
model = KeyedVectors.load('./test_50.bin')

# %%
def calculate_cosine_similarity(a, b):
    vector_a = np.mat(a)
    vector_b = np.mat(b)
    num = float(vector_a * vector_b.T)
    denom = np.linalg.norm(vector_a) * np.linalg.norm(vector_b)
    cos = num / denom
    sim = 0.5 + 0.5 * cos
    return sim

# %%
def generateEmbeddings(name):
    words = jieba.cut(name, cut_all=False)
    word_list = list(words)
    v = np.zeros((200))
    for word in word_list:
        if word in model.vocab:
            v += model[word]
    
    v /= len(v)
    return v

# %%
def calculate_IDF(df):
    company_num = 0
    m = dict()
    for index, row in df.iterrows():
        name = row['name']
        name = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", name)
        name = name.lower()
        if isinstance(name, float) or name == " ":
            continue
        company_num += 1
        words = jieba.cut(name, cut_all=False)
        word_list = list(words)
        for word in word_list:
            if word in m.keys():
                m[word] +=1
            else:
                m[word] = 1
    
    idf = dict()
    
    for (k, v) in m.items():
        idf[k] = math.log(((1+company_num) / v), 10)
    
    # Normalize min-max
    v = idf.values()
    max_value = max(v)
    min_value = min(v)
    denom = max_value - min_value
    for (k, v) in idf.items():
        idf[k] = (idf[k] - min_value) / denom

    return idf

# %%
def generateEmbeddingsWithIDF(name, idf):
    words = jieba.cut(name, cut_all=False)
    word_list = list(words)
    v = np.zeros((200))
    for word in word_list:
        if word in model.vocab:
            v += model[word] * idf[word]
    
    v /= len(v)
    return v

# %%
def preprocess_entity_list(df, model):
    '''
    df: dafaframe
    model: word embedding model
    '''
    
    df['embeddings'] = ''
    for index, row in df.iterrows():
        # df.loc[index, 'embeddings'] = z
        name = row['name']
        if isinstance(name, float):
            continue
        name = name.lower()
        if name in model.vocab:
            vec = model[name]
        else:
            vec = generateEmbeddings(name)
        df.set_value(index, 'embeddings', vec)

    # print(df.head())
    return df

# %%
def preprocess_entity_list_withIDF(df, model, idf):
    '''
    df: dafaframe
    model: word embedding model
    idf: IDF for each word
    '''
    
    df['embeddings'] = ''
    for index, row in df.iterrows():
        name = row['name']
        name = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", name)
        name = name.lower()
        if isinstance(name, float):
            continue
        if name in model.vocab:
            vec = model[name]
        else:
            vec = generateEmbeddingsWithIDF(name, idf)
        df.set_value(index, 'embeddings', vec)

    # print(df.head())
    return df

# %% [markdown]
# ## Entity Link

# %%
def linkEntity(output, model, school_df, company_df, degree_df, position_df, school_threshold, company_threshold, degree_threshold, position_threshold):
    for term in output:
        if len(term) <= 1:
            continue
        if term in model.vocab:
            term_vec = model[term]
            school_candidate = dict()
            
            # Link School
            for index, row in school_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name_vec = row['embeddings']
                sim = calculate_cosine_similarity(term_vec, name_vec)
                if (sim > school_threshold):
                    school_candidate[name] = sim
            if len(school_candidate) != 0:
                school_candidate = sorted(school_candidate.items(), key=lambda item:item[1], reverse=True)
                print(f'university entity found: {term}->{school_candidate[0][0]}, sim = {school_candidate[0][1]}')
            
            # Link Company
            company_candidate = dict()
            for index, row in company_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name_vec = row['embeddings']
                sim = calculate_cosine_similarity(term_vec, name_vec)
                if (sim > company_threshold):
                    company_candidate[name] = sim
            if len(company_candidate) != 0:
                company_candidate = sorted(company_candidate.items(), key=lambda item:item[1], reverse=True)
                print(f'company entity found: {term}->{company_candidate[0][0]}, sim = {company_candidate[0][1]}')
            
            # Link Degree
            degree_candidate = dict()
            for index, row in degree_df.iterrows():
                name = row['name']
                name_vec = row['embeddings']
                sim = calculate_cosine_similarity(term_vec, name_vec)
                if (sim > degree_threshold):
                    degree_candidate[name] = sim
            if len(degree_candidate) != 0:
                degree_candidate = sorted(degree_candidate.items(), key=lambda item:item[1], reverse=True)
                print(f'degree entity found: {term}->{degree_candidate[0][0]}, sim = {degree_candidate[0][1]}')
            
            # Link Position
            position_candidate = dict()
            for index, row in position_df.iterrows():
                name = row['name']
                name_vec = row['embeddings']
                sim = calculate_cosine_similarity(term_vec, name_vec)
                if (sim > position_threshold):
                    position_candidate[name] = sim
            if len(position_candidate) != 0:
                position_candidate = sorted(position_candidate.items(), key=lambda item:item[1], reverse=True)
                print(f'position entity found: {term}->{position_candidate[0][0]}, sim = {position_candidate[0][1]}')

# %% [markdown]
# ## Main Function

# %%
member_df = loadMember()
school_df = loadSchool()
company_df = loadCompany()
degree_df = loadDegree()
position_df = loadPosition()
# Out:
#                                               Resume
# 0  __团队成员#1__先生是公司创始人,也是中国最有影响力的商界领袖之一。1982年,__团队...
# 1  __团队成员#2__先生,现任TCL集团股份有限公司执行董事、总裁(COO)。1963年4月...
# 2  __团队成员#3__女士:1972年7月出生,中山大学法学博士,高级经济师。1993年6月至...
# 3  __团队成员#4__先生,1965年7月出生,东方电气集团党组副书记、副总经理,兼任东方电气...
# 4  __团队成员#5__女士,现任TCL多媒体集团有限公司非执行独立董事、A8新媒体集团非执行独...
#      name
# 0    北京大学
# 1  中国人民大学
# 2    清华大学
# 3  北京交通大学
# 4  北京工业大学
#                 name
# 11711       紫光股份有限公司
# 11712     紫光西部数据有限公司
# 11713  紫罗兰家纺科技股份有限公司
# 11714   卒子科技（深圳）有限公司
# 11715   卒子科技（深圳）有限公司
#   name
# 0   本科
# 1  研究生
# 2   博士
#      name
# 0   首席执行官
# 1   首席运营官
# 2   首席财务官
# 3   首席信息官
# 4  人力资源总监

# %%
school_df = preprocess_entity_list(school_df, model)
    
company_idf = calculate_IDF(company_df)
company_df = preprocess_entity_list_withIDF(company_df, model, company_idf)
    
degree_df = preprocess_entity_list(degree_df, model)
    
position_idf = calculate_IDF(position_df)
position_df = preprocess_entity_list_withIDF(position_df, model, position_idf)
# Out:
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
for index, row in member_df.iterrows():
    if index == 100:
        break
    print(f'Handle No.{index} text')
    text = row['Resume']
    segListSanitized = preprocess(text)
    output = generateNgrams(segListSanitized, 3)
    linkEntity(output, model, school_df, company_df, degree_df, position_df, 0.9, 0.96, 0.98, 0.9)
    print()
# Out:
# Handle No.0 text
# Before sanitize, len: 325. After sanitize, len: 239
# position entity found: 地区->地区销售经理, sim = 0.994823404036675
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# university entity found: 华南理工大学->华南理工大学, sim = 1.000000029802326
#
# Handle No.1 text
# Before sanitize, len: 330. After sanitize, len: 264
# university entity found: 西安交通大学->西安交通大学, sim = 1.0000000596046448
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# university entity found: 财经学院->宁波财经学院, sim = 0.9081512997142207
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# position entity found: 首席执行官->首席执行官, sim = 1.0
# position entity found: coo->首席运营官, sim = 0.9413574039936066
# position entity found: 首席运营官->首席运营官, sim = 1.0
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# company entity found: 贸易->上海顿格电子贸易有限公司, sim = 0.9545214580490833
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# position entity found: 人力资源总监->人力资源总监, sim = 1.0000000596046448
# position entity found: 执行副总裁->副总裁, sim = 0.9208562624964871
# degree entity found: 博士->博士, sim = 1.0
# position entity found: 总监->市场总监, sim = 0.9021543206068469
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.2 text
# Before sanitize, len: 134. After sanitize, len: 108
# company entity found: 总公司->上海电气（集团）总公司
# , sim = 0.9598106928213379
# company entity found: 控股集团->中运富通控股集团有限公司
# , sim = 0.9999999998383142
# company entity found: 广州->广州酷刻科技有限公司, sim = 0.976417244475874
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 中山大学->中山大学, sim = 1.0
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
#
# Handle No.3 text
# Before sanitize, len: 187. After sanitize, len: 149
# university entity found: 重庆大学->重庆大学, sim = 1.0000000596046448
# company entity found: 总公司->上海电气（集团）总公司
# , sim = 0.9598106928213379
# university entity found: 上海交通大学->上海交通大学, sim = 1.0
# company entity found: 四川->四川创燚科技有限公司, sim = 0.9791412232093466
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# university entity found: 西南财经大学->西南财经大学, sim = 1.0000000596046448
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# degree entity found: 博士->博士, sim = 1.0
# company entity found: 电气->宁格朗电气股份有限公司, sim = 0.9840627033437822
#
# Handle No.4 text
# Before sanitize, len: 126. After sanitize, len: 94
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
#
# Handle No.5 text
# Before sanitize, len: 139. After sanitize, len: 111
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 高级经理->人力资源总监, sim = 0.9071961045265198
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 云南大学->云南大学, sim = 1.0000000596046448
# university entity found: 福州大学->福州大学, sim = 1.0000000596046448
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.6 text
# Before sanitize, len: 140. After sanitize, len: 116
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 外交学院->外交学院, sim = 1.000000029802326
# position entity found: 首席运营官->首席运营官, sim = 1.0
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.7 text
# Before sanitize, len: 574. After sanitize, len: 411
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 实业->深圳市安科讯实业有限公司, sim = 0.9759846917184146
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: 广州->广州酷刻科技有限公司, sim = 0.976417244475874
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 无锡->无锡艾斐凌科技有限公司, sim = 0.9839468244259453
#
# Handle No.8 text
# Before sanitize, len: 150. After sanitize, len: 119
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# company entity found: 家电->青岛海尔智能家电科技有限公司, sim = 0.9568892009426826
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# university entity found: 西北师范大学->西北师范大学, sim = 1.0000000596046448
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.9 text
# Before sanitize, len: 115. After sanitize, len: 88
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# company entity found: 能源->上海朋迈能源科技有限公司, sim = 0.9523396395981087
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# position entity found: 首席运营官->首席运营官, sim = 1.0
# university entity found: 清华大学->清华大学, sim = 1.0
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.10 text
# Before sanitize, len: 117. After sanitize, len: 84
# university entity found: 电子科技大学->电子科技大学, sim = 1.0
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# position entity found: 研发副总裁->销售副总裁, sim = 0.9040964486656456
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9738841785569683
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: 首席运营官->首席运营官, sim = 1.0
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.11 text
# Before sanitize, len: 262. After sanitize, len: 211
# company entity found: 电子商务->北京京虹电子商务科技有限公司, sim = 0.9587409596430545
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# position entity found: 首席执行官->首席执行官, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 市场部经理->市场总监, sim = 0.9245886161678205
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# company entity found: 汽车->上海汽车集团股份有限公司
# , sim = 0.9556356986257624
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
#
# Handle No.12 text
# Before sanitize, len: 188. After sanitize, len: 124
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# degree entity found: 研究生->研究生, sim = 1.0
# company entity found: 半导体->北京芯慧联半导体科技有限公司, sim = 0.9689735263946619
# position entity found: 首席执行官->首席执行官, sim = 1.0
# position entity found: 执行副总裁->副总裁, sim = 0.9208562624964871
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# position entity found: 总监->市场总监, sim = 0.9021543206068469
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.13 text
# Before sanitize, len: 467. After sanitize, len: 372
# company entity found: 广东->广东欧怡迪科技股份有限公司, sim = 0.9624160734989036
# company entity found: 总公司->上海电气（集团）总公司
# , sim = 0.9598106928213379
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: 广州->广州酷刻科技有限公司, sim = 0.976417244475874
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# company entity found: 天津->天津日津科技股份有限公司, sim = 0.9840061128384741
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# university entity found: 武汉->武汉光谷职业学院, sim = 0.9132345485049689
# company entity found: 武汉->武汉思创易控科技有限公司, sim = 0.9820442890163562
# position entity found: 首席运营官->首席运营官, sim = 1.0
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
# company entity found: 数码科技->深圳市今视通数码科技有限公司, sim = 0.9823084859916735
# position entity found: 生产经理->生产经理, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 贸易->上海顿格电子贸易有限公司, sim = 0.9545214580490833
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
# company entity found: 网络科技->深圳市果拍网络科技有限公司, sim = 0.9793309483002404
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# degree entity found: 本科->本科, sim = 1.0
# university entity found: 华南理工大学->华南理工大学, sim = 1.000000029802326
# company entity found: 奥博->广东奥博智能科技有限公司, sim = 0.9587433574804065
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.14 text
# Before sanitize, len: 181. After sanitize, len: 141
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# university entity found: 汕头大学->汕头大学, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 集团副总裁->副总裁, sim = 0.9149988839029601
# university entity found: 南京师范大学->南京师范大学, sim = 1.000000029802326
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# position entity found: 人力资源总监->人力资源总监, sim = 1.0000000596046448
# university entity found: 中山大学->中山大学, sim = 1.0
# university entity found: 北京大学->北京大学, sim = 1.0
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.15 text
# Before sanitize, len: 127. After sanitize, len: 85
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# company entity found: 汽车->上海汽车集团股份有限公司
# , sim = 0.9556356986257624
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.16 text
# Before sanitize, len: 26. After sanitize, len: 20
# university entity found: 财经学院->宁波财经学院, sim = 0.9081512997142207
# position entity found: 高级经理->人力资源总监, sim = 0.9071961045265198
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
#
# Handle No.17 text
# Before sanitize, len: 135. After sanitize, len: 99
# position entity found: 总裁兼->首席运营官, sim = 0.9214009344577789
# position entity found: 市场经理->市场总监, sim = 0.9260545328888019
# position entity found: 市场部总经理->市场总监, sim = 0.9012132765308949
# university entity found: 首都经济贸易大学->首都经济贸易大学, sim = 1.000000029802326
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 首席营销官->首席运营官, sim = 0.9224896430969238
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# position entity found: 营销总监->市场总监, sim = 0.932394977354704
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: 产品经理->产品经理, sim = 1.0
# position entity found: 首席运营官->首席运营官, sim = 1.0
# position entity found: 高级总监->副总裁, sim = 0.9166743705674631
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.18 text
# Before sanitize, len: 16. After sanitize, len: 8
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.19 text
# Before sanitize, len: 12. After sanitize, len: 7
# position entity found: 产品经理->产品经理, sim = 1.0
#
# Handle No.20 text
# Before sanitize, len: 81. After sanitize, len: 62
# university entity found: 重庆大学->重庆大学, sim = 1.0000000596046448
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# degree entity found: 博士->博士, sim = 1.0
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# degree entity found: 研究生->研究生, sim = 1.0
#
# Handle No.21 text
# Before sanitize, len: 116. After sanitize, len: 90
# university entity found: 理工学院->潍坊理工学院, sim = 0.9093460041882638
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 卓尔->卓尔控股有限公司
# , sim = 0.9615709559228356
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
#
# Handle No.22 text
# Before sanitize, len: 90. After sanitize, len: 66
# degree entity found: 本科->本科, sim = 1.0
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
#
# Handle No.23 text
# Before sanitize, len: 310. After sanitize, len: 242
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# university entity found: 中国科学院->中国科学院大学, sim = 0.9003123641014099
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 首席技术官->首席运营官, sim = 0.930001825094223
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
#
# Handle No.24 text
# Before sanitize, len: 90. After sanitize, len: 60
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
#
# Handle No.25 text
# Before sanitize, len: 133. After sanitize, len: 109
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国建设银行->中国建设银行股份有限公司
# , sim = 0.9975220662046976
#
# Handle No.26 text
# Before sanitize, len: 220. After sanitize, len: 181
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# university entity found: 惠州学院->惠州学院, sim = 1.0
# university entity found: 湖南农业大学->湖南农业大学, sim = 1.000000029802326
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
# university entity found: 湖南->湖南工商大学, sim = 0.9128547738195922
# company entity found: 湖南->湖南恒茂高科股份有限公司, sim = 0.9930103142529615
# university entity found: 衡阳师范学院->衡阳师范学院, sim = 1.0000000596046448
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
#
# Handle No.27 text
# Before sanitize, len: 152. After sanitize, len: 116
# position entity found: 总裁兼->首席运营官, sim = 0.9214009344577789
# university entity found: 师范大学->南宁师范大学, sim = 0.9128770340491656
# position entity found: 首席技术官->首席运营官, sim = 0.930001825094223
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# degree entity found: 博士->博士, sim = 1.0
# university entity found: 华南师范大学->华南师范大学, sim = 1.0000000596046448
# company entity found: 华南->广州华南信息技术有限公司, sim = 0.961838773852374
#
# Handle No.28 text
# Before sanitize, len: 208. After sanitize, len: 166
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# university entity found: 广西大学->广西大学, sim = 1.0
# company entity found: 中国电信集团->中国电信集团有限公司
# , sim = 1.000000010344435
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
#
# Handle No.29 text
# Before sanitize, len: 172. After sanitize, len: 126
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# university entity found: 山东大学->山东大学, sim = 1.0000000596046448
# company entity found: 惠州市->惠州市耐利普科技有限公司, sim = 0.9897734262234279
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
#
# Handle No.30 text
# Before sanitize, len: 119. After sanitize, len: 89
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# company entity found: 半导体->北京芯慧联半导体科技有限公司, sim = 0.9689735263946619
# position entity found: 首席执行官->首席执行官, sim = 1.0
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
#
# Handle No.31 text
# Before sanitize, len: 99. After sanitize, len: 74
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# university entity found: 暨南大学->暨南大学, sim = 1.0
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# degree entity found: 博士->博士, sim = 1.0
# university entity found: 中国人民大学->中国人民大学, sim = 1.0
#
# Handle No.32 text
# Before sanitize, len: 12. After sanitize, len: 7
#
# Handle No.33 text
# Before sanitize, len: 178. After sanitize, len: 132
# position entity found: 总裁兼->首席运营官, sim = 0.9214009344577789
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总裁->第一副总裁, sim = 0.9138278115528521
# company entity found: tcl集团股份有限公司->TCL集团股份有限公司, sim = 1.0
# university entity found: 清华->清华大学, sim = 0.9318847615650154
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9738841785569683
# university entity found: 天津大学->天津大学, sim = 1.000000029802326
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: 高级副总裁->副总裁, sim = 0.9421679939131733
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# company entity found: 紫光股份有限公司->紫光股份有限公司, sim = 1.0
# university entity found: 清华大学->清华大学, sim = 1.0
#
# Handle No.34 text
# Before sanitize, len: 11. After sanitize, len: 5
#
# Handle No.35 text
# Before sanitize, len: 230. After sanitize, len: 172
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# company entity found: 高科技->广州力浦高科技有限公司, sim = 0.9596081900107316
# company entity found: 智慧->深圳市茵泰力智慧科技有限公司, sim = 0.9611714411039598
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 互联网->深圳酷旗互联网有限公司, sim = 0.9690650278059014
# university entity found: 商学院->郑州商学院, sim = 0.9071498487162017
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# company entity found: 教育->广州智惟高教育科技有限公司, sim = 0.9628609500760072
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# degree entity found: 博士->博士, sim = 1.0
#
# Handle No.36 text
# Before sanitize, len: 14. After sanitize, len: 8
# position entity found: 董事长->总经理, sim = 0.9022811891008132
#
# Handle No.37 text
# Before sanitize, len: 10. After sanitize, len: 5
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 艾美特->艾美特电器（深圳）有限公司, sim = 0.9692589861665224
#
# Handle No.38 text
# Before sanitize, len: 10. After sanitize, len: 5
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
#
# Handle No.39 text
# Before sanitize, len: 11. After sanitize, len: 7
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
#
# Handle No.40 text
# Before sanitize, len: 161. After sanitize, len: 110
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 电气->宁格朗电气股份有限公司, sim = 0.9840627033437822
# university entity found: 清华大学->清华大学, sim = 1.0
# company entity found: 计算机->上海荧通计算机科技有限公司, sim = 0.9709117795996929
#
# Handle No.41 text
# Before sanitize, len: 93. After sanitize, len: 68
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# degree entity found: 博士->博士, sim = 1.0
# company entity found: 电气->宁格朗电气股份有限公司, sim = 0.9840627033437822
# company entity found: 计算机->上海荧通计算机科技有限公司, sim = 0.9709117795996929
#
# Handle No.42 text
# Before sanitize, len: 38. After sanitize, len: 30
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# university entity found: 南京大学->南京大学, sim = 1.0000000596046448
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.43 text
# Before sanitize, len: 11. After sanitize, len: 6
# position entity found: 产品经理->产品经理, sim = 1.0
#
# Handle No.44 text
# Before sanitize, len: 12. After sanitize, len: 6
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
#
# Handle No.45 text
# Before sanitize, len: 16. After sanitize, len: 10
# company entity found: 新能源->上海烯美新能源科技有限公司, sim = 0.9677087225831307
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# position entity found: ceo->首席执行官, sim = 0.9130788393663668
# company entity found: 爱国者->爱国者电子科技有限公司, sim = 0.961055332960576
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
#
# Handle No.46 text
# Before sanitize, len: 16. After sanitize, len: 10
# position entity found: 高级客户经理->高级客户经理, sim = 1.000000029802326
# company entity found: 爱国者->爱国者电子科技有限公司, sim = 0.961055332960576
#
# Handle No.47 text
# Before sanitize, len: 12. After sanitize, len: 7
#
# Handle No.48 text
# Before sanitize, len: 13. After sanitize, len: 8
#
# Handle No.49 text
# Before sanitize, len: 15. After sanitize, len: 9
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 爱漫->爱漫科技（北京）有限公司, sim = 0.9737016228079585
#
# Handle No.50 text
# Before sanitize, len: 10. After sanitize, len: 5
#
# Handle No.51 text
# Before sanitize, len: 11. After sanitize, len: 6
#
# Handle No.52 text
# Before sanitize, len: 55. After sanitize, len: 42
# degree entity found: 博士->博士, sim = 1.0
# university entity found: 清华大学->清华大学, sim = 1.0
#
# Handle No.53 text
# Before sanitize, len: 53. After sanitize, len: 44
# degree entity found: 博士->博士, sim = 1.0
#
# Handle No.54 text
# Before sanitize, len: 89. After sanitize, len: 63
# position entity found: 产品总监->市场总监, sim = 0.9087868576518808
# company entity found: 网络->深圳市正星特网络有限公司, sim = 0.9704845109700312
# company entity found: 腾讯->腾讯控股有限公司
# , sim = 0.9739785986066192
# company entity found: 互联网->深圳酷旗互联网有限公司, sim = 0.9690650278059014
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.55 text
# Before sanitize, len: 60. After sanitize, len: 42
# company entity found: 教育->广州智惟高教育科技有限公司, sim = 0.9628609500760072
# position entity found: 运营总监->运营总监, sim = 1.0000000596046448
# position entity found: 总监->市场总监, sim = 0.9021543206068469
# position entity found: 联合创始人->首席运营官, sim = 0.9034993946552277
# degree entity found: 研究生->研究生, sim = 1.0
#
# Handle No.56 text
# Before sanitize, len: 58. After sanitize, len: 38
# university entity found: 武汉大学->武汉大学, sim = 1.0000000596046448
# position entity found: 联合创始人->首席运营官, sim = 0.9034993946552277
#
# Handle No.57 text
# Before sanitize, len: 27. After sanitize, len: 17
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
#
# Handle No.58 text
# Before sanitize, len: 19. After sanitize, len: 12
#
# Handle No.59 text
# Before sanitize, len: 11. After sanitize, len: 6
#
# Handle No.60 text
# Before sanitize, len: 195. After sanitize, len: 148
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
#
# Handle No.61 text
# Before sanitize, len: 148. After sanitize, len: 107
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 网络科技->深圳市果拍网络科技有限公司, sim = 0.9793309483002404
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
# company entity found: 实业->深圳市安科讯实业有限公司, sim = 0.9759846917184146
#
# Handle No.62 text
# Before sanitize, len: 125. After sanitize, len: 90
# position entity found: 营销经理->销售经理, sim = 0.9256276995691894
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.63 text
# Before sanitize, len: 156. After sanitize, len: 118
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 家电->青岛海尔智能家电科技有限公司, sim = 0.9568892009426826
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# university entity found: 南京理工大学->南京理工大学, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.64 text
# Before sanitize, len: 90. After sanitize, len: 67
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
#
# Handle No.65 text
# Before sanitize, len: 11. After sanitize, len: 6
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.66 text
# Before sanitize, len: 119. After sanitize, len: 85
# position entity found: 市场部总监->市场总监, sim = 0.9429808191038154
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
# company entity found: 重庆->重庆软汇科技股份有限公司, sim = 0.9850386960954174
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.67 text
# Before sanitize, len: 131. After sanitize, len: 101
# company entity found: 深圳->深圳坂云智行有限公司, sim = 1.000000015981282
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.68 text
# Before sanitize, len: 136. After sanitize, len: 102
# position entity found: 区域经理->销售经理, sim = 0.9318836250166447
# position entity found: 高级客户经理->高级客户经理, sim = 1.000000029802326
# company entity found: 银行->北京银行股份有限公司
# , sim = 0.9791109394306664
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.69 text
# Before sanitize, len: 11. After sanitize, len: 6
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
#
# Handle No.70 text
# Before sanitize, len: 84. After sanitize, len: 64
# company entity found: 江苏->江苏艾倍科科技股份有限公司, sim = 0.9759494769775594
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# company entity found: 实业->深圳市安科讯实业有限公司, sim = 0.9759846917184146
#
# Handle No.71 text
# Before sanitize, len: 89. After sanitize, len: 72
# company entity found: 江苏->江苏艾倍科科技股份有限公司, sim = 0.9759494769775594
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.72 text
# Before sanitize, len: 104. After sanitize, len: 77
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.73 text
# Before sanitize, len: 140. After sanitize, len: 106
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
#
# Handle No.74 text
# Before sanitize, len: 115. After sanitize, len: 85
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
#
# Handle No.75 text
# Before sanitize, len: 10. After sanitize, len: 5
# company entity found: 安德森->安德森科技股份有限公司, sim = 0.9945034379960257
# position entity found: 董事长->总经理, sim = 0.9022811891008132
#
# Handle No.76 text
# Before sanitize, len: 10. After sanitize, len: 5
# company entity found: 安德森->安德森科技股份有限公司, sim = 0.9945034379960257
# position entity found: 董事长->总经理, sim = 0.9022811891008132
#
# Handle No.77 text
# Before sanitize, len: 14. After sanitize, len: 8
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.78 text
# Before sanitize, len: 11. After sanitize, len: 6
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 董事长->总经理, sim = 0.9022811891008132
#
# Handle No.79 text
# Before sanitize, len: 11. After sanitize, len: 6
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.80 text
# Before sanitize, len: 14. After sanitize, len: 8
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.81 text
# Before sanitize, len: 18. After sanitize, len: 11
#
# Handle No.82 text
# Before sanitize, len: 133. After sanitize, len: 102
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 生产部经理->生产经理, sim = 0.9017573712161338
# position entity found: 采购经理->采购经理, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 安徽大学->安徽大学, sim = 1.000000029802326
# company entity found: 光电->深圳市耐明光电有限公司, sim = 0.9531797183825286
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.83 text
# Before sanitize, len: 123. After sanitize, len: 93
# university entity found: 中国科学技术大学->中国科学技术大学, sim = 1.0
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.84 text
# Before sanitize, len: 78. After sanitize, len: 62
# university entity found: 合肥工业大学->合肥工业大学, sim = 1.0
# position entity found: 副总经理->总经理, sim = 0.9247318804264069
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# university entity found: 安徽工业大学->安徽工业大学, sim = 1.0
# degree entity found: 研究生->研究生, sim = 1.0
# company entity found: 贸易->上海顿格电子贸易有限公司, sim = 0.9545214580490833
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.85 text
# Before sanitize, len: 121. After sanitize, len: 95
# degree entity found: 研究生->研究生, sim = 1.0
# university entity found: 南京航空航天大学->南京航空航天大学, sim = 1.000000029802326
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 南京->南京控驰科技有限公司, sim = 0.979792042693938
# university entity found: 哈尔滨理工大学->哈尔滨理工大学, sim = 1.0
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.86 text
# Before sanitize, len: 147. After sanitize, len: 110
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# university entity found: 合肥学院->合肥学院, sim = 1.0
# position entity found: 总监->市场总监, sim = 0.9021543206068469
# company entity found: 安徽省->安徽省极索智能科技有限公司, sim = 0.9685017100256157
# university entity found: 联合大学->北京联合大学, sim = 0.900326448717886
# university entity found: 大学->吉林外国语大学, sim = 0.9060334598685178
# position entity found: 销售经理->销售经理, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# position entity found: 销售总监->销售经理, sim = 0.9263566688511771
# company entity found: 计算机->上海荧通计算机科技有限公司, sim = 0.9709117795996929
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.87 text
# Before sanitize, len: 144. After sanitize, len: 107
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 商务总监->市场总监, sim = 0.9171622296765125
# company entity found: 时代->北京网河时代科技有限公司, sim = 0.9699212403890358
# position entity found: 销售经理->销售经理, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 安徽大学->安徽大学, sim = 1.000000029802326
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.88 text
# Before sanitize, len: 157. After sanitize, len: 120
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# university entity found: 合肥工业大学->合肥工业大学, sim = 1.0
# position entity found: 市场经理->市场总监, sim = 0.9260545328888019
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# position entity found: 市场总监->市场总监, sim = 1.000000029802326
#
# Handle No.89 text
# Before sanitize, len: 140. After sanitize, len: 104
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 总公司->上海电气（集团）总公司
# , sim = 0.9598106928213379
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# position entity found: 副总裁->副总裁, sim = 1.000000029802326
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 大区经理->销售经理, sim = 0.9139902787196968
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# company entity found: 发展->深圳市迈迪加科技发展有限公司, sim = 0.9571209545059199
#
# Handle No.90 text
# Before sanitize, len: 141. After sanitize, len: 106
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 大连->大连乾函科技有限公司, sim = 0.9910785478214691
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9738841785569683
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 电子工程学院->合肥工业大学, sim = 0.9056322574615479
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.91 text
# Before sanitize, len: 98. After sanitize, len: 77
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# university entity found: 财经大学->南京财经大学, sim = 0.9078076426868226
# university entity found: 安徽财经大学->安徽财经大学, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.92 text
# Before sanitize, len: 167. After sanitize, len: 129
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 科达->山东科达集团有限公司
# , sim = 0.9513994006082696
# position entity found: 区域销售经理->销售主管, sim = 0.9082846939563751
# position entity found: 销售经理->销售经理, sim = 1.0
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 北京->宝希（北京）科技有限公司, sim = 0.9572426110775603
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
# position entity found: 总监->市场总监, sim = 0.9021543206068469
#
# Handle No.93 text
# Before sanitize, len: 149. After sanitize, len: 112
# university entity found: 安徽科技学院->安徽科技学院, sim = 1.0
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 浙江->浙江鼎美智装股份有限公司, sim = 0.9817474346516779
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.94 text
# Before sanitize, len: 12. After sanitize, len: 7
# company entity found: 中电->四川中电昆辰科技有限公司, sim = 0.9508817053897032
#
# Handle No.95 text
# Before sanitize, len: 14. After sanitize, len: 8
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 中电->四川中电昆辰科技有限公司, sim = 0.9508817053897032
#
# Handle No.96 text
# Before sanitize, len: 14. After sanitize, len: 8
# position entity found: 总经理->总经理, sim = 1.0000000596046448
#
# Handle No.97 text
# Before sanitize, len: 202. After sanitize, len: 148
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# degree entity found: 研究生->研究生, sim = 1.0
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9738841785569683
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# company entity found: 能源->上海朋迈能源科技有限公司, sim = 0.9523396395981087
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.98 text
# Before sanitize, len: 14. After sanitize, len: 10
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177
#
# Handle No.99 text
# Before sanitize, len: 220. After sanitize, len: 171
# company entity found: 科技股份->华立捷科技股份有限公司, sim = 0.9999999984295314
# company entity found: 总公司->上海电气（集团）总公司
# , sim = 0.9598106928213379
# company entity found: 科技->多玛凯拔科技有限公司, sim = 1.0000000094492705
# company entity found: 深圳市->深圳市君和睿通科技股份有限公司, sim = 0.9628859211180791
# position entity found: 总经理->总经理, sim = 1.0000000596046448
# position entity found: 董事长->总经理, sim = 0.9022811891008132
# company entity found: 电子科技->深圳市奥芯博电子科技有限公司, sim = 0.9738841785569683
# company entity found: 中国->尚科宁家（中国）科技有限公司, sim = 0.9840627450595995
# university entity found: 百色学院->百色学院, sim = 1.000000029802326
# company entity found: 上海->馥德（上海）科技有限公司, sim = 0.9639796324899778
# company entity found: 安徽->安徽徽电科技股份有限公司, sim = 0.983783352873177

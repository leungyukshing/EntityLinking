# %% [markdown]
# # Experiment 1
# I try to process a specific text here.

# %%
text = '__团队成员#1__先生是公司创始人,也是中国最有影响力的商界领袖之一。1982年,__团队成员#1__先生于华南理工大学毕业,进入TCL的前身-TTK家庭电器有限公司。1985年,他担任新成立的TCL通讯设备公司总经理,创立了TCL品牌。2003年,__团队成员#1__担任TCL集团股份有限公司董事长兼CEO,随后TCL集团整体上市。在他的领导下,2004年TCL一举收购了法国汤姆逊全球彩电业务与阿尔卡特全球手机业务。目前TCL集团已经成为拥有6万名员工,业务遍及全球80多个国家和地区。2013年,TCL集团营业总收入超过855亿元,液晶电视全球销量1766万台,实际产量全球第三,品牌销售全球第三;TCL手机全球销量5520万台,行业排名全球第五。2012年__团队成员#1__被新华网评为“最具社会责任感企业家”;2011年荣获《中国企业家》“最具影响力的25位企业领袖”终身成就奖;2009年被评为“CCTV中国经济年度人物十年商业领袖”;2008年获改革开放30年经济人物称号;2004年被评为Fortune杂志“亚洲年度经济人物”、TIME杂志和CNN全球最具影响力的25名商界人士,同年法国总统希拉克向__团队成员#1__先生颁发了法国国家荣誉勋章。__团队成员#1__是中共第十六大代表,第十届、第十一届、第十二届全国人大代表。__团队成员#1__担任的社会职务包括:中国电子视像行业协会会长;中国国际商会副会长;全国工商联执行委员、广东省工商联(总商会)副主席。'

# %%
print(text)
# Out:
# __团队成员#1__先生是公司创始人,也是中国最有影响力的商界领袖之一。1982年,__团队成员#1__先生于华南理工大学毕业,进入TCL的前身-TTK家庭电器有限公司。1985年,他担任新成立的TCL通讯设备公司总经理,创立了TCL品牌。2003年,__团队成员#1__担任TCL集团股份有限公司董事长兼CEO,随后TCL集团整体上市。在他的领导下,2004年TCL一举收购了法国汤姆逊全球彩电业务与阿尔卡特全球手机业务。目前TCL集团已经成为拥有6万名员工,业务遍及全球80多个国家和地区。2013年,TCL集团营业总收入超过855亿元,液晶电视全球销量1766万台,实际产量全球第三,品牌销售全球第三;TCL手机全球销量5520万台,行业排名全球第五。2012年__团队成员#1__被新华网评为“最具社会责任感企业家”;2011年荣获《中国企业家》“最具影响力的25位企业领袖”终身成就奖;2009年被评为“CCTV中国经济年度人物十年商业领袖”;2008年获改革开放30年经济人物称号;2004年被评为Fortune杂志“亚洲年度经济人物”、TIME杂志和CNN全球最具影响力的25名商界人士,同年法国总统希拉克向__团队成员#1__先生颁发了法国国家荣誉勋章。__团队成员#1__是中共第十六大代表,第十届、第十一届、第十二届全国人大代表。__团队成员#1__担任的社会职务包括:中国电子视像行业协会会长;中国国际商会副会长;全国工商联执行委员、广东省工商联(总商会)副主席。

# %%
import jieba
import re
import chardet
from gensim.models import KeyedVectors

# %%
stopwords = {}
fstop = open('data/stopwords_cn.txt', 'r', encoding='utf-8', errors='ignore')
for w in fstop:
    stopwords[w.strip()] = w.strip()

fstop.close()
stopwords[' '] = ' '

# %%
# re.sub(r"[\s+\.\!\/_,$%^*()?;；:-【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", data)

# %%
text = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", text)
print(text)
# Out:
#  团队成员 1 先生是公司创始人 也是中国最有影响力的商界领袖之一 1982年 团队成员 1 先生于华南理工大学毕业 进入TCL的前身-TTK家庭电器有限公司 1985年 他担任新成立的TCL通讯设备公司总经理 创立了TCL品牌 2003年 团队成员 1 担任TCL集团股份有限公司董事长兼CEO 随后TCL集团整体上市 在他的领导下 2004年TCL一举收购了法国汤姆逊全球彩电业务与阿尔卡特全球手机业务 目前TCL集团已经成为拥有6万名员工 业务遍及全球80多个国家和地区 2013年 TCL集团营业总收入超过855亿元 液晶电视全球销量1766万台 实际产量全球第三 品牌销售全球第三 TCL手机全球销量5520万台 行业排名全球第五 2012年 团队成员 1 被新华网评为“最具社会责任感企业家” 2011年荣获《中国企业家》“最具影响力的25位企业领袖”终身成就奖 2009年被评为“CCTV中国经济年度人物十年商业领袖” 2008年获改革开放30年经济人物称号 2004年被评为Fortune杂志“亚洲年度经济人物” TIME杂志和CNN全球最具影响力的25名商界人士 同年法国总统希拉克向 团队成员 1 先生颁发了法国国家荣誉勋章  团队成员 1 是中共第十六大代表 第十届 第十一届 第十二届全国人大代表  团队成员 1 担任的社会职务包括 中国电子视像行业协会会长 中国国际商会副会长 全国工商联执行委员 广东省工商联 总商会 副主席

# %%
words = jieba.cut(text, cut_all=False)
seglist = list(words)
print(seglist)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\梁育诚\AppData\Local\Temp\jieba.cache
# Loading model cost 1.248 seconds.
# Prefix dict has been built succesfully.
# [' ', '团队', '成员', ' ', '1', ' ', '先生', '是', '公司', '创始人', ' ', '也', '是', '中国', '最有', '影响力', '的', '商界', '领袖', '之一', ' ', '1982', '年', ' ', '团队', '成员', ' ', '1', ' ', '先生', '于', '华南理工大学', '毕业', ' ', '进入', ' ', '的', '前身', '-', ' ', '家庭', '电器', '有限公司', ' ', '1985', '年', ' ', '他', '担任', '新', '成立', '的', ' ', '通讯设备', '公司', '总经理', ' ', '创立', '了', ' ', '品牌', ' ', '2003', '年', ' ', '团队', '成员', ' ', '1', ' ', '担任', ' ', '集团股份', '有限公司', '董事长', '兼', ' ', '随后', ' ', '集团', '整体', '上市', ' ', '在', '他', '的', '领导', '下', ' ', '2004', '年', ' ', '一举', '收购', '了', '法国', '汤姆逊', '全球', '彩电', '业务', '与', '阿尔卡特', '全球', '手机', '业务', ' ', '目前', ' ', '集团', '已经', '成为', '拥有', '6', '万名', '员工', ' ', '业务', '遍及', '全球', '80', '多个', '国家', '和', '地区', ' ', '2013', '年', ' ', '集团', '营业', '总收入', '超过', '855', '亿元', ' ', '液晶电视', '全球', '销量', '1766', '万台', ' ', '实际', '产量', '全球', '第三', ' ', '品牌', '销售', '全球', '第三', ' ', '手机', '全球', '销量', '5520', '万台', ' ', '行业', '排名', '全球', '第五', ' ', '2012', '年', ' ', '团队', '成员', ' ', '1', ' ', '被', '新华网', '评为', ' ', '最具', '社会', '责任感', '企业家', ' ', '2011', '年', '荣获', ' ', '中国', '企业家', ' ', '最具', '影响力', '的', '25', '位', '企业', '领袖', ' ', '终身', '成就奖', ' ', '2009', '年', '被', '评为', ' ', '中国', '经济', '年度人物', '十年', '商业', '领袖', ' ', '2008', '年', '获', '改革开放', '30', '年', '经济', '人物', '称号', ' ', '2004', '年', '被', '评为', ' ', '杂志', ' ', '亚洲', '年度', '经济', '人物', ' ', '杂志', '和', ' ', '全球', '最具', '影响力', '的', '25', '名', '商界', '人士', ' ', '同年', '法国', '总统', '希拉克', '向', ' ', '团队', '成员', ' ', '1', ' ', '先生', '颁发', '了', '法国', '国家', '荣誉', '勋章', ' ', '团队', '成员', ' ', '1', ' ', '是', '中共', '第十六', '大', '代表', ' ', '第十届', ' ', '第十一届', ' ', '第十二届', '全国', '人大代表', ' ', '团队', '成员', ' ', '1', ' ', '担任', '的', '社会', '职务', '包括', ' ', '中国', '电子', '视像', '行业', '协会会长', ' ', '中国', '国际商会', '副会长', ' ', '全国工商联', '执行', '委员', ' ', '广东省', '工商联', ' ', '总商会', ' ', '副', '主席', ' ']

# %%
segListSanitized = []

for word in seglist:
    if word not in stopwords:
        segListSanitized.append(word)
print(segListSanitized)
# Out:
# ['团队', '成员', '1', '先生', '公司', '创始人', '中国', '最有', '影响力', '商界', '领袖', '之一', '1982', '年', '团队', '成员', '1', '先生', '华南理工大学', '毕业', '进入', '前身', '-', '家庭', '电器', '有限公司', '1985', '年', '担任', '新', '成立', '通讯设备', '公司', '总经理', '创立', '品牌', '2003', '年', '团队', '成员', '1', '担任', '集团股份', '有限公司', '董事长', '兼', '集团', '整体', '上市', '领导', '2004', '年', '一举', '收购', '法国', '汤姆逊', '全球', '彩电', '业务', '阿尔卡特', '全球', '手机', '业务', '目前', '集团', '已经', '成为', '拥有', '6', '万名', '员工', '业务', '遍及', '全球', '80', '多个', '国家', '地区', '2013', '年', '集团', '营业', '总收入', '超过', '855', '亿元', '液晶电视', '全球', '销量', '1766', '万台', '实际', '产量', '全球', '第三', '品牌', '销售', '全球', '第三', '手机', '全球', '销量', '5520', '万台', '行业', '排名', '全球', '第五', '2012', '年', '团队', '成员', '1', '新华网', '评为', '最具', '社会', '责任感', '企业家', '2011', '年', '荣获', '中国', '企业家', '最具', '影响力', '25', '位', '企业', '领袖', '终身', '成就奖', '2009', '年', '评为', '中国', '经济', '年度人物', '十年', '商业', '领袖', '2008', '年', '获', '改革开放', '30', '年', '经济', '人物', '称号', '2004', '年', '评为', '杂志', '亚洲', '年度', '经济', '人物', '杂志', '全球', '最具', '影响力', '25', '名', '商界', '人士', '同年', '法国', '总统', '希拉克', '团队', '成员', '1', '先生', '颁发', '法国', '国家', '荣誉', '勋章', '团队', '成员', '1', '中共', '第十六', '大', '代表', '第十届', '第十一届', '第十二届', '全国', '人大代表', '团队', '成员', '1', '担任', '社会', '职务', '包括', '中国', '电子', '视像', '行业', '协会会长', '中国', '国际商会', '副会长', '全国工商联', '执行', '委员', '广东省', '工商联', '总商会', '副', '主席']

# %%
print(len(seglist))
print(len(segListSanitized))
# Out:
# 314
# 214

# %%
def getNgrams(wordList, n):
    output = set()
    for i in range (len(wordList) - n + 1):
        n_gram_temp = "".join(wordList[i:i+n])
        output.add(n_gram_temp)
    return output

# %%
output1 = getNgrams(segListSanitized, 1)
print(output1)
# Out:
# {'工商联', '1', '团队', '包括', '年度', '总经理', '年', '汤姆逊', '产量', '主席', '集团股份', '视像', '855', '副会长', '同年', '先生', '5520', '影响力', '阿尔卡特', '一举', '上市', '经济', '国家', '总商会', '成就奖', '希拉克', '领导', '电子', '全球', '2012', '代表', '委员', '企业', '销售', '企业家', '社会', '家庭', '1985', '整体', '总收入', '国际商会', '十年', '目前', '亿元', '大', '勋章', '法国', '商界', '副', '排名', '广东省', '第十六', '第十届', '通讯设备', '有限公司', '评为', '兼', '集团', '人物', '杂志', '进入', '2011', '获', '拥有', '30', '中共', '全国', '成为', '已经', '成立', '荣誉', '第十二届', '第十一届', '毕业', '创立', '彩电', '新', '称号', '终身', '领袖', '万台', '担任', '第五', '1982', '董事长', '中国', '商业', '电器', '名', '手机', '全国工商联', '25', '80', '改革开放', '位', '协会会长', '2004', '品牌', '2003', '遍及', '2013', '华南理工大学', '总统', '6', '2009', '行业', '员工', '前身', '责任感', '颁发', '人士', '之一', '创始人', '最具', '最有', '年度人物', '亚洲', '公司', '-', '荣获', '第三', '多个', '收购', '2008', '成员', '1766', '销量', '实际', '业务', '地区', '职务', '执行', '液晶电视', '超过', '营业', '万名', '新华网', '人大代表'}

# %%
output2 = getNgrams(segListSanitized, 2)
print(output2)
# Out:
# {'颁发法国', '产量全球', '年担任', '员工业务', '勋章团队', '彩电业务', '全球第五', '6万名', '年评为', '-家庭', '已经成为', '有限公司1985', '第十六大', '职务包括', '商界人士', '万台行业', '位企业', '企业领袖', '全球手机', '25名', '第三品牌', '有限公司董事长', '人物称号', '阿尔卡特全球', '总商会副', '十年商业', '商业领袖', '1新华网', '30年', '领袖之一', '5520万台', '前身-', '中国最有', '销售全球', '兼集团', '最具影响力', '工商联总商会', '手机业务', '中国经济', '希拉克团队', '先生颁发', '称号2004', '先生华南理工大学', '人物杂志', '新成立', '行业排名', '品牌2003', '名商界', '杂志亚洲', '公司创始人', '收购法国', '1982年', '副主席', '创始人中国', '领袖2008', '执行委员', '杂志全球', '大代表', '一举收购', '获改革开放', '经济年度人物', '代表第十届', '全国人大代表', '年一举', '集团整体', '之一1982', '成就奖2009', '电器有限公司', '委员广东省', '进入前身', '董事长兼', '法国汤姆逊', '企业家2011', '全球最具', '万名员工', '年度经济', '家庭电器', '商界领袖', '年经济', '1766万台', '集团已经', '责任感企业家', '广东省工商联', '年度人物十年', '业务目前', '销量5520', '影响力25', '毕业进入', '协会会长中国', '销量1766', '第十一届第十
'副会长', '第三品牌', '同年', '有限公司董事长', '人物称号', '阿尔卡特全球', '排名全球第五', '超过855亿元', '十年商业', '阿尔卡特', '商业领袖', '30年', '全球销量1766', '第十届第十一届第十二届', '前身-', '领导2004年', '经济', '2009年评为', '最具影响力', '希拉克', '手机业务', '希拉克团队', '领导', '电子', '先生颁发', '全球', '称号2004', '总商会副主席', '新成立', '行业排名', '品牌2003', '名商界', '名商界人士', '公司创始人', '企业', '1982年', '副主席', '1先生华南理工大学', '执行委员', '企业家', '社会', '杂志全球', '副会长全国工商联执行', '获改革开放', '家庭', '成为拥有6', '电子视像行业', '1985', '总收入', '年一举', '集团整体', '国际商会', '之一1982', '董事长兼集团', '2004年评为', '成员1先生', '董事长兼', '法国汤姆逊', '十年', '企业家2011', '1985年担任', '万名员工', '年度经济', '亿元', '广东省工商联', '年度人物十年', '有限公司1985年', '创立品牌2003', '协会会长中国', '商界', '荣获中国企业家', '全球销量5520', '第十一届第十二届', '称号2004年', '视像行业协会会长', '第十届', '通讯设备公司总经理', '职务包括中国', '拥有6', '影响力商界', '收购法国汤姆逊', '2013年', '实际产量全球', '成员1新华网', '先生华南理工大学毕业', '亿元液晶电视', '第十届第十一届', '有限公司', '领袖终身', '超过855', '亿元液晶电视全球', '成就奖2009年', '评为', '社会责任感企业家', '评为中国', '全球80', '营业总收入', '影响力25名', '2003年', '担任集团股份有限公司', '集团营业', '团队成员1', '企业家最具', '人物', '年度经济人物', '评为中国经济', '进入', '获', '全国', '国家地区', '销量1766万台', '已经', '荣誉', '第十二届', '人士同年', '总经理创立', '25位', '万台行业排名', '改革开放30', '年荣获中国', '年担任新', '创立', '成员1担任', '5520万台行业', '彩电', '新', '855亿元', '荣获中国', '影响力商界领袖', '担任', '董事长', '评为杂志', '电器有限公司1985', '最具社会责任感', '委员广东省工商联', '商业', '电器', '全国工商联', '手机', '中国国际商会', '社会职务包括', '国际商会副会长全国工商联', '年评为杂志', '80', '改革开放', '先生公司', '最有影响力', '中国电子视像', '2004', '遍及', '2003', '成员1', '之一1982年', '团队成员', '上市领导', '中国国际商会副会长', '2013', '华南理工大学', '新华网评为', '年集团', '国际商会副会长', '总统', '年一举收购', '视像行业', '全国工商联执行', '行业协会会长中国', '液晶电视全球', '2009', '第三手机', ...

# %%
model = KeyedVectors.load('./test.bin')

# %%
v = model['已经成为']
model.most_similar('TCL集团')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-b6dcdd42ecd8> in <module>
#       1 v = model['已经成为']
# ----> 2 model.most_similar('TCL集团')
#
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# c:\users\梁育诚\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'TCL集团' not in vocabulary"

# %%
for term in final:
    if term in model.vocab:
        print('match!')
        print(term)
# Out:
# match!
# 工商联
# match!
# 包括
# match!
# 总经理
# match!
# 已经成为
# match!
# 汤姆逊
# match!
# 主席
# match!
# 商界人士
# match!
# 企业领袖
# match!
# 全球手机
# match!
# 先生
# match!
# 5520
# match!
# 影响力
# match!
# 一举
# match!
# 上市
# match!
# 国家
# match!
# 总商会
# match!
# 成就奖
# match!
# 中国经济
# match!
# 2012
# match!
# 代表
# match!
# 委员
# match!
# 销售
# match!
# 全国人大代表
# match!
# 整体
# match!
# 电器有限公司
# match!
# 目前
# match!
# 家庭电器
# match!
# 商界领袖
# match!
# 大
# match!
# 勋章
# match!
# 法国
# match!
# 副
# match!
# 排名
# match!
# 广东省
# match!
# 第十六
# match!
# 品牌销售
# match!
# 通讯设备
# match!
# 兼
# match!
# 集团
# match!
# 杂志
# match!
# 2011
# match!
# 30
# match!
# 拥有
# match!
# 中共
# match!
# 成为
# match!
# 成立
# match!
# 第十一届
# match!
# 毕业
# match!
# 2009年
# match!
# 称号
# match!
# 终身
# match!
# 领袖
# match!
# 2011年
# match!
# 万台
# match!
# 第五
# match!
# 1982
# match!
# 中国
# match!
# 名
# match!
# 25
# match!
# 公司总经理
# match!
# 2012年
# match!
# 协会会长
# match!
# 品牌
# match!
# 社会职务
# match!
# 6
# match!
# 行业
# match!
# 整体上市
# match!
# 责任感
# match!
# 荣誉勋章
# match!
# 颁发
# match!
# 人士
# match!
# 创始人
# match!
# 最具
# match!
# 最有
# match!
# 年度人物
# match!
# 中国企业家
# match!
# 公司
# match!
# 全球销量
# match!
# 2004年
# match!
# 中国电子
# match!
# 2008
# match!
# 遍及全球
# match!
# 成员
# match!
# 执行
# match!
# 地区
# match!
# 职务
# match!
# 业务遍及
# match!
# 位
# match!
# 万名
# match!
# 新华网
# match!
# 1
# match!
# 团队
# match!
# 年度
# match!
# 年
# match!
# 产量
# match!
# 视像
# match!
# 25名
# match!
# 855
# match!
# 副会长
# match!
# 同年
# match!
# 阿尔卡特
# match!
# 商业领袖
# match!
# 30年
# match!
# 经济
# match!
# 最具影响力
# match!
# 希拉克
# match!
# 手机业务
# match!
# 领导
# match!
# 电子
# match!
# 全球
# match!
# 新成立
# match!
# 行业排名
# match!
# 公司创始人
# match!
# 企业
# match!
# 1982年
# match!
# 副主席
# match!
# 执行委员
# match!
# 企业家
# match!
# 社会
# match!
# 家庭
# match!
# 1985
# match!
# 总收入
# match!
# 国际商会
# match!
# 十年
# match!
# 亿元
# match!
# 商界
# match!
# 第十届
# match!
# 2013年
# match!
# 有限公司
# match!
# 评为
# match!
# 营业总收入
# match!
# 2003年
# match!
# 人物
# match!
# 进入
# match!
# 获
# match!
# 全国
# match!
# 国家地区
# match!
# 已经
# match!
# 荣誉
# match!
# 第十二届
# match!
# 25位
# match!
# 创立
# match!
# 彩电
# match!
# 新
# match!
# 担任
# match!
# 董事长
# match!
# 商业
# match!
# 电器
# match!
# 全国工商联
# match!
# 手机
# match!
# 80
# match!
# 改革开放
# match!
# 最有影响力
# match!
# 2004
# match!
# 遍及
# match!
# 2003
# match!
# 团队成员
# match!
# 2013
# match!
# 华南理工大学
# match!
# 总统
# match!
# 2009
# match!
# 创立品牌
# match!
# 员工
# match!
# 前身
# match!
# 法国总统
# match!
# 多个国家
# match!
# 包括中国
# match!
# 集团股份有限公司
# match!
# 社会责任感
# match!
# 之一
# match!
# 国家荣誉
# match!
# 亚洲
# match!
# -
# match!
# 荣获
# match!
# 第三
# match!
# 多个
# match!
# 收购
# match!
# 1766
# match!
# 销量
# match!
# 1985年
# match!
# 实际产量
# match!
# 实际
# match!
# 业务
# match!
# 2008年
# match!
# 改革开放30年
# match!
# 终身成就奖
# match!
# 液晶电视
# match!
# 超过
# match!
# 营业
# match!
# 人大代表

# %%
import pandas as pd
path0 = 'data/chinese_university_list.csv'

# %%
df = pd.read_csv(path0, header=None, delimiter=",", skiprows=4, names=["rank", "name", "code", "department", "city", "level", "notes"])
print(df.head())
df['embeddings'] = ''
print(df.head())
# Out:
#   rank    name          code department city level notes
# 0    1    北京大学  4.111010e+09        教育部  北京市    本科   NaN
# 1    2  中国人民大学  4.111010e+09        教育部  北京市    本科   NaN
# 2    3    清华大学  4.111010e+09        教育部  北京市    本科   NaN
# 3    4  北京交通大学  4.111010e+09        教育部  北京市    本科   NaN
# 4    5  北京工业大学  4.111010e+09        北京市  北京市    本科   NaN
#   rank    name          code department city level notes embeddings
# 0    1    北京大学  4.111010e+09        教育部  北京市    本科   NaN
# 1    2  中国人民大学  4.111010e+09        教育部  北京市    本科   NaN
# 2    3    清华大学  4.111010e+09        教育部  北京市    本科   NaN
# 3    4  北京交通大学  4.111010e+09        教育部  北京市    本科   NaN
# 4    5  北京工业大学  4.111010e+09        北京市  北京市    本科   NaN

# %%
for index, row in df.iterrows():
    if row['name'] in model.vocab:
        print('match!')
        row['embeddings'] = 12
        
print(df.head())
# Out:
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
#   rank    name          code department city level notes embeddings
# 0    1    北京大学  4.111010e+09        教育部  北京市    本科   NaN
# 1    2  中国人民大学  4.111010e+09        教育部  北京市    本科   NaN
# 2    3    清华大学  4.111010e+09        教育部  北京市    本科   NaN
# 3    4  北京交通大学  4.111010e+09        教育部  北京市    本科   NaN
# 4    5  北京工业大学  4.111010e+09        北京市  北京市    本科   NaN

# %%
df = pd.DataFrame(df, columns=['rank', 'name'])
print(df.head())
print(df.shape)
# Out:
#   rank    name
# 0    1    北京大学
# 1    2  中国人民大学
# 2    3    清华大学
# 3    4  北京交通大学
# 4    5  北京工业大学
# (2718, 2)

# %%
for index, row in df.iterrows():
    if row['name'] in model.vocab:
        print('match!')
        df.at[index,'embeddings'] = model[row['name']]
        
print(df.head())
# Out:
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
# match!
#   rank    name
# 0    1    北京大学
# 1    2  中国人民大学
# 2    3    清华大学
# 3    4  北京交通大学
# 4    5  北京工业大学

# %%
for index, row in df.iterrows():
    print(index, row['rank'], row['name'])

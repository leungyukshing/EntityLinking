# %% [markdown]
# # Exact Match Algorithm
# In this notebook, an exact match demo will be completed, acting as a comparison to the present model.
#
# Author: Yucheng Liang

# %% [markdown]
# ## Import libs

# %%
import jieba
import re
import chardet
import pandas as pd
import prettytable as pt

# %% [markdown]
# ## Load File
# Generate Knowledge Base for matching

# %%
def loadSchool():
    path1 = 'data/chinese_university_list.csv'
    school_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=4, names=["rank", "name", "code", "department", "city", "level", "notes"])
    school_df = pd.DataFrame(school_df, columns=['name'])
    
    path2 = 'data/all_university_list.csv'
    school_global_df = pd.read_csv(path2, header=None, delimiter=',', skiprows=2, names=['Name_en', 'name', 'rank', 'score', 'location'])
    school_global_df = pd.DataFrame(school_global_df, columns=['name'])
    
    school_df = pd.concat([school_df, school_global_df], axis=0, ignore_index=True)
    return school_df

# %%
def loadDegree():
    degree = {'name': ['本科', '硕士' ,'研究生', '博士']}
    degree_df = pd.DataFrame(degree)
    return degree_df

# %%
def loadCompany():
    path1 = 'data/company_list_ch.csv'
    company_ch_df = pd.read_csv(path1, header=None, delimiter=",", skiprows=2, names=['rank', 'name', 'Location', 'Income'])
    company_ch_df = pd.DataFrame(company_ch_df, columns=['name'])
    path2 = 'data/member-data.csv'
    company_df = pd.read_csv(path2, header=None, delimiter=",", skiprows=2, names=['name', 'No.', 'Resume', 'Position'])
    company_df = pd.DataFrame(company_df, columns=['name'])
    company_ch_df = pd.concat([company_ch_df, company_df], axis=0, ignore_index=True)
    
    print(f'before dedup, company size: {company_ch_df.shape[0]}')
    company_ch_df = company_ch_df.drop_duplicates(subset=['name'], keep='first')
    print(f'after dedup, company size: {company_ch_df.shape[0]}')
    return company_ch_df

# %%
def loadPosition():
    path5 = 'data/position.csv'
    position_df1 = pd.read_csv(path5, header=None, delimiter=",", skiprows=1, names=['name'])
    position_df1 = pd.DataFrame(position_df1)

    path6 = 'data/member-data.csv'
    position_df2 = pd.read_csv(path6, header=None, delimiter=",", skiprows=1, names=['Company', 'No.', 'Resume', 'name'])
    position_df2 = pd.DataFrame(position_df2, columns=['name'])

    member_position_list = []
    # process position in member-data
    for index, row in position_df2.iterrows():
        position = row['name']
        if isinstance(position, float) or position == " " or position.isalpha():
            continue
        if "&" in position:
            temp1 = position.split('&')
            member_position_list += temp1
        elif " " in position:
            temp2 = position.split( )
            member_position_list += temp2
        else:
            member_position_list.append(position)

    position_df3 = pd.DataFrame(member_position_list, columns=['name'])
    position_df1 = pd.concat([position_df1, position_df3], axis=0, ignore_index=True)
    print(f'before dedup, position size: {position_df1.shape[0]}')
    position_df1 = position_df1.drop_duplicates(subset=['name'], keep='first')
    print(f'after dedup, position size: {position_df1.shape[0]}')
    # print(df1.head())
    return position_df1

# %%
def loadMember():
    path = 'data/member-data.csv'
    member_df = pd.read_csv(path, header=None, delimiter=",", skiprows=1, names=['Company', 'No.', 'Resume', 'Position'])
    member_df = pd.DataFrame(member_df, columns=['Resume'])
    return member_df

# %% [markdown]
# ## Preprocess Text

# %%
def removeStopWords(seglist):
    stopwords = {}
    fstop = open('data/stopwords_cn.txt', 'r', encoding='utf-8', errors='ignore')
    for w in fstop:
        stopwords[w.strip()] = w.strip()

    fstop.close()
    stopwords[' '] = ' '
    
    segListSanitized = []

    for word in seglist:
        # translation
        if word == 'omnigo':
            word = '酷刻'
        if word == 'Aibee':
            word = '爱笔'
        if word == 'ilife':
            word = '爱乐福'
        if word == 'oracleen':
            word = '爱芽'
        if word not in stopwords:
            segListSanitized.append(word)
    return segListSanitized

# %%
def preprocess(text):
    # remove punctuations
    text = re.sub(r"[\s+\.\!\/_,$%^*()?;；:【】+\"\']+|[+——！，;:。？、~@#￥%……&*（）]+", " ", text)
    text = text.lower()
    # seperate words
    words = jieba.cut(text, cut_all=False)
    seglist = list(words)
    # remove stopwords
    segListSanitized = removeStopWords(seglist)
    print(f'Before sanitize, len: {len(seglist)}. After sanitize, len: {len(segListSanitized)}')

    return segListSanitized

# %% [markdown]
# ## N-gram Algorithm

# %%
def getNgrams(wordList, n):
    '''
    This function only generete N-Grams
    '''
    output = []
    for i in range (len(wordList) - n + 1):
        n_gram_temp = "".join(wordList[i:i+n])
        output.append(n_gram_temp)
    return output

# %%
def generateNgramsV2(wordList, n):
    '''
    This function genereates [1, N]-Grams
    '''
    result = []
    for i in range(n):
        temp_list = getNgrams(wordList, i+1)
        temp = list(set(temp_list))
        temp.sort(key=temp_list.index)
        result.append(temp)
        
    return result

# %% [markdown]
# ## Entity Link

# %%
def linkEntity(output, company_df, position_df, school_df, degree_df, f):
    company_entity = []
    position_entity = []
    school_entity = []
    degree_entity = []
    for index, li in enumerate(output):
        print(f'process {index}-Gram')
        print(f'process {index}-Gram', file=f)
        for term in li:
            if len(term) <= 1:
                continue
            
            # Link Company
            for index, row in company_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name = name.lower()
                if term == name:
                    company_entity.append(term)
                    print(f'company entity found: {term}')
                    print(f'company entity found: {term}', file=f)
            
            # Link Position
            for index, row in position_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name = name.lower()
                if term == name:
                    position_entity.append(term)
                    print(f'position entity found: {term}')
                    print(f'position entity found: {term}', file=f)
            
            # Link School
            for index, row in school_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name = name.lower()
                if term == name:
                    school_entity.append(term)
                    print(f'school entity found: {term}')
                    print(f'school entity found: {term}', file=f)
            
            # Link Degree
            for index, row in degree_df.iterrows():
                name = row['name']
                if isinstance(name, float):
                    continue
                name = name.lower()
                if term == name:
                    degree_entity.append(term)
                    print(f'degree entity found: {term}')
                    print(f'degree entity found: {term}', file=f)
            
    return company_entity, position_entity, school_entity, degree_entity

# %%
def print_table_company_position(company_entity, position_entity, f):
    company_list = []
    position_list = []
        
    min_len = min(len(company_entity), len(position_entity))
    
    for i, s in enumerate(company_entity):
        if i == min_len:
            break
        company_list.append(s)

    for i, d in enumerate(position_entity):
        if i == min_len:
            break
        position_list.append(d)

    tb = pt.PrettyTable()
    tb.add_column("Company", company_list)
    tb.add_column("Position", position_list)
    print(tb)
    print(tb, file=f)

# %%
def print_table_school_degree(school_entity, degree_entity, f):
    school_list = []
    degree_list = []

    if len(degree_entity) == 0:
        d = dict()
        d= '本科'
        degree_entity.append(d)
        
    min_len = min(len(school_entity), len(degree_entity))
    
    for i, s in enumerate(school_entity):
        if i == min_len:
            break
        school_list.append(s)

    for i, d in enumerate(degree_entity):
        if i == min_len:
            break
        degree_list.append(d)

    tb = pt.PrettyTable()
    tb.add_column("School", school_list)
    tb.add_column("Degree", degree_list)
    print(tb)
    print(tb, file=f)

# %%
def print_table(company_entity, position_entity, school_entity, degree_entity, f):
    print_table_company_position(company_entity, position_entity, f)
    print_table_school_degree(school_entity, degree_entity, f)

# %% [markdown]
# ## Case Test

# %%
company_df = loadCompany()
position_df = loadPosition()
school_df = loadSchool()
degree_df = loadDegree()
member_df = loadMember()
# Out:
# before dedup, company size: 11716
# after dedup, company size: 3571
# before dedup, position size: 5983
# after dedup, position size: 199

# %%
text1 = '__团队成员#1__先生是公司创始人,也是中国最有影响力的商界领袖之一。1982年,__团队成员#1__先生于华南理工大学毕业,进入TCL的前身-TTK家庭电器有限公司。1985年,他担任新成立的TCL通讯设备公司总经理,创立了TCL品牌。2003年,__团队成员#1__担任TCL集团股份有限公司董事长兼CEO,随后TCL集团整体上市。在他的领导下,2004年TCL一举收购了法国汤姆逊全球彩电业务与阿尔卡特全球手机业务。目前TCL集团已经成为拥有6万名员工,业务遍及全球80多个国家和地区。2013年,TCL集团营业总收入超过855亿元,液晶电视全球销量1766万台,实际产量全球第三,品牌销售全球第三;TCL手机全球销量5520万台,行业排名全球第五。2012年__团队成员#1__被新华网评为“最具社会责任感企业家”;2011年荣获《中国企业家》“最具影响力的25位企业领袖”终身成就奖;2009年被评为“CCTV中国经济年度人物十年商业领袖”;2008年获改革开放30年经济人物称号;2004年被评为Fortune杂志“亚洲年度经济人物”、TIME杂志和CNN全球最具影响力的25名商界人士,同年法国总统希拉克向__团队成员#1__先生颁发了法国国家荣誉勋章。__团队成员#1__是中共第十六大代表,第十届、第十一届、第十二届全国人大代表。__团队成员#1__担任的社会职务包括:中国电子视像行业协会会长;中国国际商会副会长;全国工商联执行委员、广东省工商联(总商会)副主席。'

# %% [markdown]
# ## batch process

# %%
import datetime

# %%
begin = 8800
finish = 8850
time_arr = []
f = open('output_batch_exact_10.txt', "w", encoding="utf-8")
for index, row in member_df.iterrows():
    if index < begin:
        continue
    if index > finish:
        break
    print(f'Handle No.{index} text')
    print(f'Handle No.{index} text', file=f)
    start = datetime.datetime.now()
    text = row['Resume']
    segListSanitized = preprocess(text)
    output = generateNgramsV2(segListSanitized, 3)
    end0 = datetime.datetime.now()
    company_entity, position_entity, school_entity, degree_entity = linkEntity(output, company_df, position_df, school_df, degree_df, f)
    end1 = datetime.datetime.now()
    print_table(company_entity, position_entity, school_entity, degree_entity, f)
    print()
    end = datetime.datetime.now()
    print(f'cost time(proprocess): {end0 - start} sec')
    print(f'cost time(proprocess): {end0 - start} sec', file=f)
    print(f'cost time(match): {end1 - end0} sec')
    print(f'cost time(match): {end1 - end0} sec', file=f)
    print(f'cost time(e2e): {end - start} sec')
    print(f'cost time(e2e): {end - start} sec', file=f)
    time_arr.append(end-start)
    print('\n\n')
    print('\n\n', file=f)
    

total_time = datetime.timedelta(0)
for t in time_arr:
    total_time += t
    
avg_time = total_time / len(time_arr)
print('avg_time: ', avg_time)
print('avg_time: ', avg_time, file=f)
f.close()
# Out:
# Handle No.8800 text
# Before sanitize, len: 29. After sanitize, len: 21
# process 0-Gram
# degree entity found: 本科
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001957 sec
# cost time(match): 0:00:24.908167 sec
# cost time(e2e): 0:00:24.911123 sec
#
#
#
# Handle No.8801 text
# Before sanitize, len: 30. After sanitize, len: 23
# process 0-Gram
# degree entity found: 本科
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001995 sec
# cost time(match): 0:00:25.439006 sec
# cost time(e2e): 0:00:25.442000 sec
#
#
#
# Handle No.8802 text
# Before sanitize, len: 45. After sanitize, len: 37
# process 0-Gram
# degree entity found: 研究生
# position entity found: 经理
# position entity found: 总工程师
# process 1-Gram
# position entity found: 高级工程师
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.003020 sec
# cost time(match): 0:00:42.922981 sec
# cost time(e2e): 0:00:42.927000 sec
#
#
#
# Handle No.8803 text
# Before sanitize, len: 18. After sanitize, len: 13
# process 0-Gram
# degree entity found: 本科
# process 1-Gram
# position entity found: 高级工程师
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002005 sec
# cost time(match): 0:00:15.611040 sec
# cost time(e2e): 0:00:15.614046 sec
#
#
#
# Handle No.8804 text
# Before sanitize, len: 14. After sanitize, len: 10
# process 0-Gram
# position entity found: 监事
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001971 sec
# cost time(match): 0:00:12.317059 sec
# cost time(e2e): 0:00:12.320032 sec
#
#
#
# Handle No.8805 text
# Before sanitize, len: 415. After sanitize, len: 347
# process 0-Gram
# degree entity found: 本科
# position entity found: 部长
# position entity found: 监事
# process 1-Gram
# position entity found: 监事会主席
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.015037 sec
# cost time(match): 0:03:15.831961 sec
# cost time(e2e): 0:03:15.848000 sec
#
#
#
# Handle No.8806 text
# Before sanitize, len: 159. After sanitize, len: 135
# process 0-Gram
# degree entity found: 本科
# position entity found: 部长
# position entity found: 总经理
# position entity found: 副总经理
# position entity found: 董事长
# process 1-Gram
# position entity found: 高级工程师
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.006012 sec
# cost time(match): 0:01:54.782985 sec
# cost time(e2e): 0:01:54.789997 sec
#
#
#
# Handle No.8807 text
# Before sanitize, len: 40. After sanitize, len: 35
# process 0-Gram
# degree entity found: 研究生
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002003 sec
# cost time(match): 0:00:34.505045 sec
# cost time(e2e): 0:00:34.508022 sec
#
#
#
# Handle No.8808 text
# Before sanitize, len: 11. After sanitize, len: 6
# process 0-Gram
# position entity found: 董事长
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.000983 sec
# cost time(match): 0:00:06.486001 sec
# cost time(e2e): 0:00:06.486984 sec
#
#
#
# Handle No.8809 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001001 sec
# cost time(match): 0:00:07.928997 sec
# cost time(e2e): 0:00:07.930998 sec
#
#
#
# Handle No.8810 text
# Before sanitize, len: 10. After sanitize, len: 5
# process 0-Gram
# position entity found: 创始人
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.000999 sec
# cost time(match): 0:00:05.123048 sec
# cost time(e2e): 0:00:05.124999 sec
#
#
#
# Handle No.8811 text
# Before sanitize, len: 27. After sanitize, len: 18
# process 0-Gram
# position entity found: ceo
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.003002 sec
# cost time(match): 0:00:22.183996 sec
# cost time(e2e): 0:00:22.188000 sec
#
#
#
# Handle No.8812 text
# Before sanitize, len: 31. After sanitize, len: 21
# process 0-Gram
# position entity found: cto
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.003016 sec
# cost time(match): 0:00:25.759023 sec
# cost time(e2e): 0:00:25.762039 sec
#
#
#
# Handle No.8813 text
# Before sanitize, len: 28. After sanitize, len: 19
# process 0-Gram
# position entity found: 市场总监
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002004 sec
# cost time(match): 0:00:23.422994 sec
# cost time(e2e): 0:00:23.426001 sec
#
#
#
# Handle No.8814 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# position entity found: 董事
# position entity found: 总经理
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001012 sec
# cost time(match): 0:00:09.291030 sec
# cost time(e2e): 0:00:09.293000 sec
#
#
#
# Handle No.8815 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# position entity found: 董事
# position entity found: 总经理
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001998 sec
# cost time(match): 0:00:09.393003 sec
# cost time(e2e): 0:00:09.395997 sec
#
#
#
# Handle No.8816 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002005 sec
# cost time(match): 0:00:11.414997 sec
# cost time(e2e): 0:00:11.419027 sec
#
#
#
# Handle No.8817 text
# Before sanitize, len: 14. After sanitize, len: 8
# process 0-Gram
# position entity found: 董事
# position entity found: 总经理
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001998 sec
# cost time(match): 0:00:12.103998 sec
# cost time(e2e): 0:00:12.106996 sec
#
#
#
# Handle No.8818 text
# Before sanitize, len: 200. After sanitize, len: 171
# process 0-Gram
# degree entity found: 硕士
# position entity found: 部长
# position entity found: 副总经理
# position entity found: 总经理
# position entity found: 董事
# position entity found: 董事长
# process 1-Gram
# position entity found: 高级工程师
# position entity found: 常务副总经理
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.008005 sec
# cost time(match): 0:02:53.609046 sec
# cost time(e2e): 0:02:53.617051 sec
#
#
#
# Handle No.8819 text
# Before sanitize, len: 12. After sanitize, len: 7
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001005 sec
# cost time(match): 0:00:07.932993 sec
# cost time(e2e): 0:00:07.933998 sec
#
#
#
# Handle No.8820 text
# Before sanitize, len: 16. After sanitize, len: 11
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001000 sec
# cost time(match): 0:00:13.176043 sec
# cost time(e2e): 0:00:13.178043 sec
#
#
#
# Handle No.8821 text
# Before sanitize, len: 53. After sanitize, len: 42
# process 0-Gram
# position entity found: 监事
# position entity found: 副总经理
# position entity found: 总经理
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002966 sec
# cost time(match): 0:00:46.594021 sec
# cost time(e2e): 0:00:46.598972 sec
#
#
#
# Handle No.8822 text
# Before sanitize, len: 61. After sanitize, len: 46
# process 0-Gram
# degree entity found: 研究生
# degree entity found: 硕士
# position entity found: 部长
# position entity found: 副总裁
# position entity found: 副总经理
# position entity found: 董事
# process 1-Gram
# school entity found: 电子科技大学
# position entity found: 高级工程师
# position entity found: 执行副总裁
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 电子科技大学 | 研究生 |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.003991 sec
# cost time(match): 0:00:54.782000 sec
# cost time(e2e): 0:00:54.787993 sec
#
#
#
# Handle No.8823 text
# Before sanitize, len: 96. After sanitize, len: 69
# process 0-Gram
# degree entity found: 博士
# position entity found: 副总经理
# position entity found: 财务总监
# position entity found: 总会计师
# position entity found: 副董事长
# position entity found: 总经理
# position entity found: 董事长
# process 1-Gram
# school entity found: 电子科技大学
# position entity found: 常务副总经理
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 电子科技大学 |  博士  |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.002998 sec
# cost time(match): 0:01:14.194000 sec
# cost time(e2e): 0:01:14.198000 sec
#
#
#
# Handle No.8824 text
# Before sanitize, len: 83. After sanitize, len: 63
# process 0-Gram
# school entity found: 西南财经大学
# degree entity found: 硕士
# degree entity found: 研究生
# school entity found: 四川大学
# school entity found: 四川大学
# position entity found: 部长
# position entity found: 副总裁
# position entity found: 副总经理
# process 1-Gram
# position entity found: 执行副总裁
# position entity found: 董事会秘书
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 西南财经大学 |  硕士  |
# |   四川大学   | 研究生 |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.003001 sec
# cost time(match): 0:01:15.464995 sec
# cost time(e2e): 0:01:15.468998 sec
#
#
#
# Handle No.8825 text
# Before sanitize, len: 89. After sanitize, len: 66
# process 0-Gram
# school entity found: 四川大学
# school entity found: 四川大学
# position entity found: 副总经理
# position entity found: 部长
# position entity found: 董事
# position entity found: 总工程师
# position entity found: 副总裁
# process 1-Gram
# position entity found: 高级工程师
# position entity found: 执行副总裁
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 四川大学 |  本科  |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.002013 sec
# cost time(match): 0:01:18.032982 sec
# cost time(e2e): 0:01:18.035998 sec
#
#
#
# Handle No.8826 text
# Before sanitize, len: 114. After sanitize, len: 86
# process 0-Gram
# degree entity found: 硕士
# degree entity found: 研究生
# position entity found: 经理
# position entity found: 副总经理
# position entity found: 部长
# position entity found: 总经理
# position entity found: 董事
# process 1-Gram
# school entity found: 格拉斯哥大学
# position entity found: 常务副总经理
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 格拉斯哥大学 |  硕士  |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.004002 sec
# cost time(match): 0:01:38.219043 sec
# cost time(e2e): 0:01:38.224049 sec
#
#
#
# Handle No.8827 text
# Before sanitize, len: 29. After sanitize, len: 19
# process 0-Gram
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002002 sec
# cost time(match): 0:00:24.523996 sec
# cost time(e2e): 0:00:24.525998 sec
#
#
#
# Handle No.8828 text
# Before sanitize, len: 73. After sanitize, len: 53
# process 0-Gram
# position entity found: 部长
# position entity found: 副总裁
# process 1-Gram
# position entity found: 监事会主席
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002005 sec
# cost time(match): 0:00:58.556993 sec
# cost time(e2e): 0:00:58.560010 sec
#
#
#
# Handle No.8829 text
# Before sanitize, len: 42. After sanitize, len: 30
# process 0-Gram
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002988 sec
# cost time(match): 0:00:37.170996 sec
# cost time(e2e): 0:00:37.175986 sec
#
#
#
# Handle No.8830 text
# Before sanitize, len: 78. After sanitize, len: 63
# process 0-Gram
# degree entity found: 博士
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.004000 sec
# cost time(match): 0:01:13.991999 sec
# cost time(e2e): 0:01:13.997001 sec
#
#
#
# Handle No.8831 text
# Before sanitize, len: 129. After sanitize, len: 93
# process 0-Gram
# school entity found: 哈尔滨工程大学
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------------+--------+
# |     School     | Degree |
# +----------------+--------+
# | 哈尔滨工程大学 |  本科  |
# +----------------+--------+
#
# cost time(proprocess): 0:00:00.004001 sec
# cost time(match): 0:01:29.652996 sec
# cost time(e2e): 0:01:29.658998 sec
#
#
#
# Handle No.8832 text
# Before sanitize, len: 124. After sanitize, len: 96
# process 0-Gram
# degree entity found: 博士
# degree entity found: 研究生
# school entity found: 清华大学
# school entity found: 清华大学
# school entity found: 悉尼大学
# school entity found: 香港中文大学
# position entity found: 董事
# process 1-Gram
# school entity found: 新南威尔士大学
# position entity found: 独立董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 清华大学 |  博士  |
# | 清华大学 | 研究生 |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.004994 sec
# cost time(match): 0:01:49.106001 sec
# cost time(e2e): 0:01:49.112995 sec
#
#
#
# Handle No.8833 text
# Before sanitize, len: 64. After sanitize, len: 44
# process 0-Gram
# school entity found: 中国政法大学
# position entity found: 董事
# process 1-Gram
# position entity found: 独立董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 中国政法大学 |  本科  |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.003001 sec
# cost time(match): 0:00:57.358999 sec
# cost time(e2e): 0:00:57.363001 sec
#
#
#
# Handle No.8834 text
# Before sanitize, len: 100. After sanitize, len: 75
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# position entity found: 独立董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.004000 sec
# cost time(match): 0:01:30.561996 sec
# cost time(e2e): 0:01:30.566996 sec
#
#
#
# Handle No.8835 text
# Before sanitize, len: 66. After sanitize, len: 48
# process 0-Gram
# degree entity found: 硕士
# position entity found: 监事
# process 1-Gram
# position entity found: 职工监事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002000 sec
# cost time(match): 0:00:59.191000 sec
# cost time(e2e): 0:00:59.194001 sec
#
#
#
# Handle No.8836 text
# Before sanitize, len: 78. After sanitize, len: 56
# process 0-Gram
# degree entity found: 研究生
# position entity found: 部长
# position entity found: 监事
# position entity found: 总工程师
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002000 sec
# cost time(match): 0:01:06.172043 sec
# cost time(e2e): 0:01:06.175043 sec
#
#
#
# Handle No.8837 text
# Before sanitize, len: 40. After sanitize, len: 28
# process 0-Gram
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002961 sec
# cost time(match): 0:00:34.402996 sec
# cost time(e2e): 0:00:34.406956 sec
#
#
#
# Handle No.8838 text
# Before sanitize, len: 76. After sanitize, len: 59
# process 0-Gram
# position entity found: 监事
# process 1-Gram
# position entity found: 职工监事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.003018 sec
# cost time(match): 0:01:04.156984 sec
# cost time(e2e): 0:01:04.161002 sec
#
#
#
# Handle No.8839 text
# Before sanitize, len: 92. After sanitize, len: 69
# process 0-Gram
# school entity found: 四川大学
# school entity found: 四川大学
# position entity found: 部长
# position entity found: 监事
# process 1-Gram
# position entity found: 财务负责人
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 四川大学 |  本科  |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.003002 sec
# cost time(match): 0:01:21.649041 sec
# cost time(e2e): 0:01:21.652043 sec
#
#
#
# Handle No.8840 text
# Before sanitize, len: 73. After sanitize, len: 58
# process 0-Gram
# school entity found: 重庆大学
# school entity found: 重庆大学
# degree entity found: 硕士
# degree entity found: 研究生
# position entity found: 财务总监
# position entity found: 经理
# position entity found: 部长
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 重庆大学 |  硕士  |
# | 重庆大学 | 研究生 |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.001997 sec
# cost time(match): 0:01:10.785996 sec
# cost time(e2e): 0:01:10.788994 sec
#
#
#
# Handle No.8841 text
# Before sanitize, len: 63. After sanitize, len: 43
# process 0-Gram
# position entity found: 合伙人
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002014 sec
# cost time(match): 0:00:53.034988 sec
# cost time(e2e): 0:00:53.037002 sec
#
#
#
# Handle No.8842 text
# Before sanitize, len: 49. After sanitize, len: 37
# process 0-Gram
# school entity found: 四川大学
# school entity found: 四川大学
# degree entity found: 硕士
# degree entity found: 博士
# school entity found: 西南财经大学
# process 1-Gram
# process 2-Gram
# school entity found: 皇家墨尔本理工大学
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 四川大学 |  硕士  |
# | 四川大学 |  博士  |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.003003 sec
# cost time(match): 0:00:47.859033 sec
# cost time(e2e): 0:00:47.862999 sec
#
#
#
# Handle No.8843 text
# Before sanitize, len: 69. After sanitize, len: 53
# process 0-Gram
# school entity found: 中国人民大学
# school entity found: 中国人民大学
# degree entity found: 博士
# school entity found: 清华大学
# school entity found: 清华大学
# position entity found: 董事
# process 1-Gram
# position entity found: 独立董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 中国人民大学 |  博士  |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.003000 sec
# cost time(match): 0:01:07.642002 sec
# cost time(e2e): 0:01:07.646002 sec
#
#
#
# Handle No.8844 text
# Before sanitize, len: 68. After sanitize, len: 52
# process 0-Gram
# position entity found: 经理
# position entity found: 部长
# process 1-Gram
# process 2-Gram
# school entity found: 西南科技大学
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------------+--------+
# |    School    | Degree |
# +--------------+--------+
# | 西南科技大学 |  本科  |
# +--------------+--------+
#
# cost time(proprocess): 0:00:00.003002 sec
# cost time(match): 0:01:00.954039 sec
# cost time(e2e): 0:01:00.957997 sec
#
#
#
# Handle No.8845 text
# Before sanitize, len: 85. After sanitize, len: 62
# process 0-Gram
# position entity found: 监事
# position entity found: 部长
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.002000 sec
# cost time(match): 0:01:10.435045 sec
# cost time(e2e): 0:01:10.438043 sec
#
#
#
# Handle No.8846 text
# Before sanitize, len: 98. After sanitize, len: 72
# process 0-Gram
# school entity found: 清华大学
# school entity found: 清华大学
# degree entity found: 博士
# degree entity found: 研究生
# position entity found: 副总经理
# position entity found: 副董事长
# position entity found: 总经理
# position entity found: 董事长
# process 1-Gram
# position entity found: 高级工程师
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 清华大学 |  博士  |
# | 清华大学 | 研究生 |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.002960 sec
# cost time(match): 0:01:19.943063 sec
# cost time(e2e): 0:01:19.947026 sec
#
#
#
# Handle No.8847 text
# Before sanitize, len: 63. After sanitize, len: 43
# process 0-Gram
# degree entity found: 本科
# degree entity found: 硕士
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.003001 sec
# cost time(match): 0:00:54.180998 sec
# cost time(e2e): 0:00:54.183999 sec
#
#
#
# Handle No.8848 text
# Before sanitize, len: 13. After sanitize, len: 8
# process 0-Gram
# position entity found: 董事
# process 1-Gram
# position entity found: 执行董事
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001001 sec
# cost time(match): 0:00:08.869999 sec
# cost time(e2e): 0:00:08.872001 sec
#
#
#
# Handle No.8849 text
# Before sanitize, len: 104. After sanitize, len: 76
# process 0-Gram
# position entity found: 董事长
# school entity found: 杜克大学
# degree entity found: 博士
# position entity found: 算法
# process 1-Gram
# school entity found: 电子科技大学
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +----------+--------+
# |  School  | Degree |
# +----------+--------+
# | 杜克大学 |  博士  |
# +----------+--------+
#
# cost time(proprocess): 0:00:00.003000 sec
# cost time(match): 0:01:37.834998 sec
# cost time(e2e): 0:01:37.837998 sec
#
#
#
# Handle No.8850 text
# Before sanitize, len: 55. After sanitize, len: 37
# process 0-Gram
# position entity found: ceo
# process 1-Gram
# process 2-Gram
# +---------+----------+
# | Company | Position |
# +---------+----------+
# +---------+----------+
# +--------+--------+
# | School | Degree |
# +--------+--------+
# +--------+--------+
#
# cost time(proprocess): 0:00:00.001997 sec
# cost time(match): 0:00:42.965999 sec
# cost time(e2e): 0:00:42.968995 sec
#
#
#
# avg_time:  0:00:53.384872
